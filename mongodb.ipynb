# %%
#############Connecting
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
# import ObjectId
from bson import ObjectId
import datetime
import json
uri = "mongodb+srv://mongoAdmin:ESiN65ToylzRhOis@cluster0.deup10k.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
##############QUERYING
db = client.sample_mflix
print(db.list_collection_names())

movies = db['movies']
res= movies.find().limit(10)
for m in res:
    print(m)
print('-----------------')
movies = db['comments']
res= movies.find().limit(10)
for m in res:
    print(m)
# Out:
# ['movies', 'theaters', 'sessions', 'users', 'comments', 'embedded_movies']
# {'_id': ObjectId('573a1390f29313caabcd42e8'), 'plot': 'A group of bandits stage a brazen train hold-up, only to find a determined posse hot on their heels.', 'genres': ['Short', 'Western'], 'runtime': 11, 'cast': ['A.C. Abadie', "Gilbert M. 'Broncho Billy' Anderson", 'George Barnes', 'Justus D. Barnes'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3NjE5NzYtYTYyNS00MDVmLWIwYjgtMmYwYWIxZDYyNzU2XkEyXkFqcGdeQXVyNzQzNzQxNzI@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Great Train Robbery', 'fullplot': "Among the earliest existing films in American cinema - notable as the first film that presented a narrative story to tell - it depicts a group of cowboy outlaws who hold up a train and rob the passengers. They are then pursued by a Sheriff's posse. Several scenes have color included - all hand tinted.", 'languages': ['English'], 'released': datetime.datetime(1903, 12, 1, 0, 0), 'directors': ['Edwin S. Porter'], 'rated': 'TV-G', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-13 00:27:59.177000000', 'year': 1903, 'imdb': {'rating': 7.4, 'votes': 9847, 'id': 439}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 2559, 'meter': 75}, 'fresh': 6, 'critic': {'rating': 7.6, 'numReviews': 6, 'meter': 100}, 'rotten': 0, 'lastUpdated': datetime.datetime(2015, 8, 8, 19, 16, 10)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a1390f29313caabcd446f'), 'plot': "A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film...", 'genres': ['Short', 'Drama'], 'runtime': 14, 'cast': ['Frank Powell', 'Grace Henderson', 'James Kirkwood', 'Linda Arvidson'], 'num_mflix_comments': 1, 'title': 'A Corner in Wheat', 'fullplot': "A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film continues to contrast the ironic differences between the lives of those who work to grow the wheat and the life of the man who dabbles in its sale for profit.", 'languages': ['English'], 'released': datetime.datetime(1909, 12, 13, 0, 0), 'directors': ['D.W. Griffith'], 'rated': 'G', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-13 00:46:30.660000000', 'year': 1909, 'imdb': {'rating': 6.6, 'votes': 1375, 'id': 832}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 109, 'meter': 73}, 'lastUpdated': datetime.datetime(2015, 5, 11, 18, 36, 53)}}
# {'_id': ObjectId('573a1390f29313caabcd4803'), 'plot': 'Cartoon figures announce, via comic strip balloons, that they will move - and move they do, in a wildly exaggerated style.', 'genres': ['Animation', 'Short', 'Comedy'], 'runtime': 7, 'cast': ['Winsor McCay'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BYzg2NjNhNTctMjUxMi00ZWU4LWI3ZjYtNTI0NTQxNThjZTk2XkEyXkFqcGdeQXVyNzg5OTk2OA@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics', 'fullplot': 'Cartoonist Winsor McCay agrees to create a large set of drawings that will be photographed and made into a motion picture. The job requires plenty of drawing supplies, and the cartoonist must also overcome some mishaps caused by an assistant. Finally, the work is done, and everyone can see the resulting animated picture.', 'languages': ['English'], 'released': datetime.datetime(1911, 4, 8, 0, 0), 'directors': ['Winsor McCay', 'J. Stuart Blackton'], 'writers': ['Winsor McCay (comic strip "Little Nemo in Slumberland")', 'Winsor McCay (screenplay)'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-29 01:09:03.030000000', 'year': 1911, 'imdb': {'rating': 7.3, 'votes': 1034, 'id': 1737}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 89, 'meter': 47}, 'lastUpdated': datetime.datetime(2015, 8, 20, 18, 51, 24)}}
# {'_id': ObjectId('573a1390f29313caabcd4eaf'), 'plot': 'A woman, with the aid of her police officer sweetheart, endeavors to uncover the prostitution ring that has kidnapped her sister, and the philanthropist who secretly runs it.', 'genres': ['Crime', 'Drama'], 'runtime': 88, 'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BYzk0YWQzMGYtYTM5MC00NjM2LWE5YzYtMjgyNDVhZDg1N2YzXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg', 'title': 'Traffic in Souls', 'lastupdated': '2015-09-15 02:07:14.247000000', 'languages': ['English'], 'released': datetime.datetime(1913, 11, 24, 0, 0), 'directors': ['George Loane Tucker'], 'rated': 'TV-PG', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'year': 1913, 'imdb': {'rating': 6.0, 'votes': 371, 'id': 3471}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 85, 'meter': 57}, 'dvd': datetime.datetime(2008, 8, 26, 0, 0), 'lastUpdated': datetime.datetime(2015, 8, 10, 18, 33, 55)}}
# {'_id': ObjectId('573a1390f29313caabcd50e5'), 'plot': 'The cartoonist, Winsor McCay, brings the Dinosaurus back to life in the figure of his latest creation, Gertie the Dinosaur.', 'genres': ['Animation', 'Short', 'Comedy'], 'runtime': 12, 'cast': ['Winsor McCay', 'George McManus', 'Roy L. McCardell'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNzI4ODQ3NF5BMl5BanBnXkFtZTgwNzY5NzMwMjE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Gertie the Dinosaur', 'fullplot': 'Winsor Z. McCay bets another cartoonist that he can animate a dinosaur. So he draws a big friendly herbivore called Gertie. Then he get into his own picture. Gertie walks through the picture, eats a tree, meets her creator, and takes him carefully on her back for a ride.', 'languages': ['English'], 'released': datetime.datetime(1914, 9, 15, 0, 0), 'directors': ['Winsor McCay'], 'writers': ['Winsor McCay'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-18 01:03:15.313000000', 'year': 1914, 'imdb': {'rating': 7.3, 'votes': 1837, 'id': 4008}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 29}, 'lastUpdated': datetime.datetime(2015, 8, 10, 19, 20, 3)}}
# {'_id': ObjectId('573a1390f29313caabcd516c'), 'plot': 'Original advertising for the film describes it as a drama of primitive life on the shores of the North Pacific...', 'genres': ['Drama', 'History'], 'runtime': 65, 'cast': ['Stanley Hunt', 'Sarah Constance Smith Hunt', 'Mrs. George Walkus', "Paddy 'Malid"], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjE3MjAyNzM5NV5BMl5BanBnXkFtZTgwMjA5OTg5NjE@._V1_SY1000_SX677_AL_.jpg', 'title': 'In the Land of the Head Hunters', 'lastupdated': '2015-09-16 12:11:37.770000000', 'languages': ['English'], 'released': datetime.datetime(1914, 12, 7, 0, 0), 'directors': ['Edward S. Curtis'], 'writers': ['Edward S. Curtis (story)'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'year': 1914, 'imdb': {'rating': 5.8, 'votes': 223, 'id': 4150}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.7, 'numReviews': 64, 'meter': 18}, 'dvd': datetime.datetime(2000, 8, 15, 0, 0), 'website': 'http://www.milestonefilms.com/', 'production': 'World Film Corporation', 'lastUpdated': datetime.datetime(2015, 8, 18, 19, 21, 12)}}
# {'_id': ObjectId('573a1390f29313caabcd5293'), 'plot': "Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle's secretary has been named as her guardian until she marries, at which time she will officially take ...", 'genres': ['Action'], 'runtime': 199, 'cast': ['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Josè'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMzgxODk1Mzk2Ml5BMl5BanBnXkFtZTgwMDg0NzkwMjE@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Perils of Pauline', 'fullplot': 'Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle\'s secretary has been named as her guardian until she marries, at which time she will officially take possession of her inheritance. Meanwhile, her "guardian" and his confederates constantly come up with schemes to get rid of Pauline so that he can get his hands on the money himself.', 'languages': ['English'], 'released': datetime.datetime(1914, 3, 23, 0, 0), 'directors': ['Louis J. Gasnier', 'Donald MacKenzie'], 'writers': ['Charles W. Goddard (screenplay)', 'Basil Dickey (screenplay)', 'Charles W. Goddard (novel)', 'George B. Seitz', 'Bertram Millhauser'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-09-12 00:01:18.647000000', 'year': 1914, 'imdb': {'rating': 7.6, 'votes': 744, 'id': 4465}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 9}, 'production': 'Pathè Frères', 'lastUpdated': datetime.datetime(2015, 9, 11, 17, 46, 19)}}
# {'_id': ObjectId('573a1390f29313caabcd56df'), 'plot': 'An immigrant leaves his sweetheart in Italy to find a better life across the sea in the grimy slums of New York. They are eventually reunited and marry. But life in New York is hard and ...', 'genres': ['Drama'], 'runtime': 78, 'rated': 'PASSED', 'cast': ['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'], 'title': 'The Italian', 'fullplot': 'An immigrant leaves his sweetheart in Italy to find a better life across the sea in the grimy slums of New York. They are eventually reunited and marry. But life in New York is hard and tragedy tarnishes their dream of a better life in the new world.', 'languages': ['English'], 'released': datetime.datetime(1915, 1, 1, 0, 0), 'directors': ['Reginald Barker'], 'writers': ['Thomas H. Ince (story)', 'C. Gardner Sullivan (story)'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-07-27 00:07:43.230000000', 'year': 1915, 'imdb': {'rating': 6.4, 'votes': 175, 'id': 5557}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 204, 'meter': 60}, 'dvd': datetime.datetime(2008, 8, 26, 0, 0), 'lastUpdated': datetime.datetime(2015, 7, 24, 19, 30, 2)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a1390f29313caabcd587d'), 'plot': 'At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the ...', 'genres': ['Biography', 'Crime', 'Drama'], 'runtime': 72, 'rated': 'PASSED', 'cast': ['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BNDkxZGU4NmMtODJlNy00YzA2LTg4ZGMtNGFlNzAyNzcxOTM1XkEyXkFqcGdeQXVyOTM3MjcyMjI@._V1_SY1000_SX677_AL_.jpg', 'title': 'Regeneration', 'fullplot': 'At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the street. By 17, Owen learns that might is right. By 25, Owen is the leader of his own gang who spend most of their time gambling and drinking. But Marie comes into the gangster area of town and everything changes for Owen as he falls for Marie. But he cannot tell her so, so he comes to her settlement to find education and inspiration. But soon, his old way of life will rise to confront him again.', 'languages': ['English'], 'released': datetime.datetime(1915, 9, 13, 0, 0), 'directors': ['Raoul Walsh'], 'writers': ['Owen Frawley Kildare (book)', 'Raoul Walsh (adapted from the book: "My Mamie Rose")', 'Carl Harbaugh (adapted from the book: "My Mamie Rose")'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-14 01:28:18.957000000', 'year': 1915, 'imdb': {'rating': 6.8, 'votes': 626, 'id': 5960}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 395, 'meter': 70}, 'dvd': datetime.datetime(2001, 11, 27, 0, 0), 'critic': {'rating': 9.2, 'numReviews': 5, 'meter': 100}, 'lastUpdated': datetime.datetime(2015, 9, 17, 17, 22, 42), 'rotten': 0, 'production': 'Fox Film Corporation', 'fresh': 5}}
# {'_id': ObjectId('573a1390f29313caabcd5a93'), 'plot': 'Christ takes on the form of a pacifist count to end a senseless war.', 'genres': ['Drama'], 'runtime': 78, 'cast': ['Howard C. Hickman', 'Enid Markey', 'Lola May', 'Kate Bruce'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjAwNTIxMjE5N15BMl5BanBnXkFtZTgwODc1Mjg1MzE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Civilization', 'fullplot': 'Allegorical film about peace. A king starts a war, many of the women are against it, people are pressed into service. A count has constructed a submarine and gets the order to sink an ocean liner, that is also carrying - supposedly - ammunition for the enemy. The count refuses to fire the torpedos, and sinks the submarine. He survives, but in a limbo between death and life where he meets Jesus, who takes him over to preach peace. Naturally the king arrests him and sentences him to death for treason, but then Jesus shows him the real face of war.', 'countries': ['USA'], 'released': datetime.datetime(1916, 6, 2, 0, 0), 'directors': ['Reginald Barker', 'Thomas H. Ince', 'Raymond B. West', 'Walter Edwards', 'David Hartford', 'Jay Hunt', 'J. Parker Read Jr.'], 'writers': ['C. Gardner Sullivan'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-04-30 02:13:27.863000000', 'year': 1916, 'imdb': {'rating': 6.3, 'votes': 162, 'id': 6517}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 7}, 'lastUpdated': datetime.datetime(2015, 8, 7, 18, 42, 35)}}
# -----------------
# {'_id': ObjectId('5a9427648b0beebeb69579e7'), 'name': 'Mercedes Tyler', 'email': 'mercedes_tyler@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd4323'), 'text': 'Eius veritatis vero facilis quaerat fuga temporibus. Praesentium expedita sequi repellat id. Corporis minima enim ex. Provident fugit nisi dignissimos nulla nam ipsum aliquam.', 'date': datetime.datetime(2002, 8, 18, 4, 56, 7)}
# {'_id': ObjectId('5a9427648b0beebeb69579f5'), 'name': 'John Bishop', 'email': 'john_bishop@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd446f'), 'text': 'Id error ab at molestias dolorum incidunt. Non deserunt praesentium dolorem nihil. Optio tempora vel ut quas.\nMinus dicta numquam quasi. Rem totam cumque at eum. Ullam hic ut ea magni.', 'date': datetime.datetime(1975, 1, 21, 0, 31, 22)}
# {'_id': ObjectId('5a9427648b0beebeb6957a21'), 'name': "Jaqen H'ghar", 'email': 'tom_wlaschiha@gameofthron.es', 'movie_id': ObjectId('573a1390f29313caabcd516c'), 'text': 'Minima odit officiis minima nam. Aspernatur id reprehenderit eius inventore amet laudantium. Eos unde enim recusandae fugit sint.', 'date': datetime.datetime(1981, 11, 8, 4, 32, 25)}
# {'_id': ObjectId('5a9427648b0beebeb6957a22'), 'name': 'Taylor Scott', 'email': 'taylor_scott@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd4eaf'), 'text': 'Iure laboriosam quo et necessitatibus sed. Id iure delectus soluta. Quaerat officiis maiores commodi earum. Autem odio labore debitis optio libero.', 'date': datetime.datetime(1970, 11, 15, 5, 54, 2)}
# {'_id': ObjectId('5a9427648b0beebeb6957a38'), 'name': 'Yara Greyjoy', 'email': 'gemma_whelan@gameofthron.es', 'movie_id': ObjectId('573a1390f29313caabcd587d'), 'text': 'Nobis incidunt ea tempore cupiditate sint. Itaque beatae hic ut quis.', 'date': datetime.datetime(2012, 11, 26, 11, 0, 57)}
# {'_id': ObjectId('5a9427648b0beebeb6957a4b'), 'name': 'Gregor Clegane', 'email': 'hafthór_júlíus_björnsson@gameofthron.es', 'movie_id': ObjectId('573a1390f29313caabcd5b9a'), 'text': 'Voluptatum voluptatem nam et accusamus ullam qui explicabo exercitationem. Ut sint facilis aut similique dolorum non. Necessitatibus unde molestias incidunt asperiores nesciunt molestias.', 'date': datetime.datetime(2015, 2, 8, 1, 28, 23)}
# {'_id': ObjectId('5a9427648b0beebeb6957a88'), 'name': 'Thomas Morris', 'email': 'thomas_morris@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd680a'), 'text': 'Perspiciatis sequi nesciunt maiores. Molestiae earum odio voluptas animi ipsam. Dolorem libero temporibus omnis quaerat deleniti atque. Tempore delectus esse explicabo nemo.', 'date': datetime.datetime(2004, 2, 26, 6, 33, 3)}
# {'_id': ObjectId('5a9427648b0beebeb6957aa3'), 'name': 'Yolanda Owen', 'email': 'yolanda_owen@fakegmail.com', 'movie_id': ObjectId('573a1391f29313caabcd6d40'), 'text': 'Occaecati commodi quidem aliquid delectus dolores. Facilis fugiat soluta maxime ipsum. Facere quibusdam vitae eius in fugit voluptatum beatae.', 'date': datetime.datetime(1980, 7, 13, 6, 41, 13)}
# {'_id': ObjectId('5a9427648b0beebeb6957abd'), 'name': 'John Bishop', 'email': 'john_bishop@fakegmail.com', 'movie_id': ObjectId('573a1391f29313caabcd6f98'), 'text': 'Accusamus qui distinctio ut ab saepe tenetur. Quae optio aut eius deleniti veritatis error. Eligendi ducimus rerum recusandae doloribus. Natus quisquam expedita voluptatum voluptatibus natus quidem.', 'date': datetime.datetime(1972, 4, 16, 14, 52, 53)}
# {'_id': ObjectId('5a9427648b0beebeb6957ac8'), 'name': 'Olenna Tyrell', 'email': 'diana_rigg@gameofthron.es', 'movie_id': ObjectId('573a1391f29313caabcd70b4'), 'text': 'Sed iste tenetur ut. Veritatis deserunt iusto blanditiis similique reprehenderit. Expedita voluptas voluptatibus exercitationem odit. Saepe culpa dolorem error nulla.', 'date': datetime.datetime(2007, 6, 27, 20, 27, 44)}

# %%
###############INSERT NEW VALUES

{'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd4323'), 'text': 'Really great movie', 'date': datetime.datetime(2024, 3, 21, 4, 56, 7)}

comments = db['comments']
comments.insert_one({'name': 'MyDiffName', 'email': 'yaour@fakegmail.com', 'movie_id': {"$oid":'573a1390f29313caabcd4323'}, 'text': 'Really great movie', "date":{"$date":{"$numberLong":"1029646567000"}}}
)
# Out:
# InsertOneResult(ObjectId('660196ae57a2008af397c63d'), acknowledged=True)

# %%
########### FINDING YOUR DATE

res= comments.find({'name': 'MyName'})
for m in res:
    print(m)


############################
# Out:
# {'_id': ObjectId('65fbae4915e1ca5bf2b99b1b'), 'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': {'$oid': '573a1390f29313caabcd4323'}, 'text': 'Really great movie', 'date': {'$date': {'$numberLong': '1029646567000'}}}
# {'_id': ObjectId('65fbaf5315e1ca5bf2b99b1c'), 'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': {'$oid': '573a1390f29313caabcd4323'}, 'text': 'Really great movie', 'date': {'$date': {'$numberLong': '1029646567000'}}}
# {'_id': ObjectId('65fbaf5d15e1ca5bf2b99b1d'), 'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': {'$oid': '573a1390f29313caabcd4323'}, 'text': 'Really great movie', 'date': {'$date': {'$numberLong': '1029646567000'}}}
# ['sell_stock_request', 'default', 'new_collection', 'test', 'comments']

# %% [markdown]
# # Connect to our DB

# %%
db = client.locth
db.list_collection_names()
# Out:
# ['default', 'VideoTranscript']

# %% [markdown]
# ## Create collection: VideoTranscript

# %%
video_transcript = db.create_collection('VideoTranscript')
# Out:
# ---------------------------------------------------------------------------
# CollectionInvalid                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 video_transcript = db.create_collection('VideoTranscript')
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/database.py:467, in Database.create_collection(self, name, codec_options, read_preference, write_concern, read_concern, session, check_exists, **kwargs)
#     459 with self.__client._tmp_session(session) as s:
#     460     # Skip this check in a transaction where listCollections is not
#     461     # supported.
#     462     if (
#     463         check_exists
#     464         and (not s or not s.in_transaction)
#     465         and name in self.list_collection_names(filter={"name": name}, session=s)
#     466     ):
# --> 467         raise CollectionInvalid("collection %s already exists" % name)
#     468     return Collection(
#     469         self,
#     470         name,
#    (...)
#     477         **kwargs,
#     478     )
#
# CollectionInvalid: collection VideoTranscript already exists

# %%
db.list_collection_names()
# Out:
# ['default', 'VideoTranscript']

# %%
video_transcript = db['VideoTranscript']

# %% [markdown]
# ## The schema for VideoTranscript is as follows:

# %%
# Define the schema for SingleEvent
single_event_schema = {
    "id": "se_1",
    "timestamp": datetime.datetime.now(),
    "event_type": "interaction",
    "description": "This is an example description"
}

# Define the schema for VideoEvent
video_event_schema = {
    "recording_id": "vd_1",
    "lesson_id": "ls_1",
    "created_at": datetime.datetime.now(),
    "modified_at": datetime.datetime.now(),
    "events": {
        "event_1_id": single_event_schema,
    }
}

# Define the schema for VideoTranscript
video_transcript_schema = {
    "id": "vt_1",
    "video_id": "vd_1",
    "body": video_event_schema,
    "created_at": datetime.datetime.now(),
    "updated_at": datetime.datetime.now()
}

# Insert sample data into the collection
video_transcript.insert_one(video_transcript_schema)

# Define function to insert new records into VideoTranscript collection
def insert_video_transcript_record(video_id, body):
    new_record = {
        "id": f"{ObjectId()}",
        "video_id": video_id,
        "body": body,
        "created_at": datetime.datetime.now(),
        "updated_at": datetime.datetime.now()
    }
    video_transcript.insert_one(new_record)
    return new_record

# Example usage:
new_video_transcript_record = insert_video_transcript_record("vd_2", video_event_schema)
print(new_video_transcript_record)
# Out:
# {'id': '6606294ea5f28dacd3a5852a', 'video_id': 'vd_2', 'body': {'recording_id': 'vd_1', 'lesson_id': 'ls_1', 'created_at': datetime.datetime(2024, 3, 29, 9, 37, 2, 481519), 'modified_at': datetime.datetime(2024, 3, 29, 9, 37, 2, 481521), 'events': {'event_1_id': {'id': 'se_1', 'timestamp': datetime.datetime(2024, 3, 29, 9, 37, 2, 481449), 'event_type': 'interaction', 'description': 'This is an example description'}}}, 'created_at': datetime.datetime(2024, 3, 29, 9, 37, 2, 536720), 'updated_at': datetime.datetime(2024, 3, 29, 9, 37, 2, 536730), '_id': ObjectId('6606294ea5f28dacd3a5852b')}

# %%
video_transcript.find({"id": "vt_1"}).next()
# Out:
# {'_id': ObjectId('6601a07857a2008af397cb69'),
#  'id': 'vt_1',
#  'video_id': 'vd_1',
#  'body': {'recording_id': 'vd_1',
#   'lesson_id': 'ls_1',
#   'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'modified_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'events': {'event_1_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_2_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_3_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_4_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_5_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 10, 38, 731000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_6_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_7_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_8_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_9_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_10_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_11_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_12_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_13_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_14_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_15_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_16_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_17_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_18_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_19_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_20_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_21_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_22_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_23_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_24_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_25_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_26_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_27_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_28_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_29_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_30_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_31_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_32_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_33_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_34_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_35_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_36_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_37_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_38_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_39_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_40_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_41_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_42_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_43_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_44_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_45_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_46_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_47_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_48_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_49_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_50_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_51_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_52_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_53_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_54_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_55_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_56_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_57_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_58_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_59_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_60_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_61_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_62_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_63_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_64_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_65_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_66_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_67_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_68_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_69_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_70_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_71_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_72_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_73_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_74_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_75_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_76_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_77_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_78_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_79_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_80_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_81_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_82_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_83_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_84_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_85_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_86_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_87_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_88_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_89_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_90_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_91_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_92_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_93_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_94_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_95_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_96_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_97_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_98_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_99_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_100_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_101_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_102_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_103_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_104_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_105_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_106_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_107_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_108_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_109_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_110_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_111_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_112_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_113_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_114_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_115_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_116_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_117_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_118_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_119_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_120_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_121_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_122_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_123_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_124_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_125_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_126_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_127_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_128_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_129_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_130_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_131_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_132_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_133_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_134_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_135_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_136_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_137_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_138_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_139_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_140_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_141_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_142_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_143_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_144_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_145_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_146_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_147_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_148_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_149_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_150_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_151_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_152_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_153_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_154_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_155_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_156_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_157_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_158_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_159_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_160_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_161_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_162_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_163_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_164_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_165_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_166_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_167_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_168_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_169_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_170_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_171_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_172_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_173_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_174_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_175_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_176_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_177_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_178_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_179_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_180_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_181_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_182_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_183_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_184_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_185_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_186_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_187_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_188_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_189_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_190_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_191_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_192_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_193_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_194_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_195_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_196_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_197_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_198_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_199_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_200_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_201_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_202_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_203_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_204_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_205_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_206_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_207_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_208_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_209_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_210_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_211_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_212_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_213_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_214_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_215_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_216_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_217_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_218_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_219_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_220_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_221_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_222_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_223_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_224_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_225_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_226_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_227_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_228_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_229_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_230_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_231_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_232_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_233_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_234_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_235_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_236_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_237_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_238_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_239_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_240_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_241_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_242_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_243_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_244_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_245_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_246_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_247_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_248_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_249_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_250_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_251_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_252_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_253_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_254_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_255_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_256_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_257_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_258_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_259_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_260_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_261_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_262_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_263_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_264_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_265_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_266_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_267_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_268_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_269_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_270_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_271_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_272_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_273_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_274_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_275_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_276_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_277_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_278_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_279_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_280_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_281_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_282_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_283_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_284_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_285_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_286_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_287_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_288_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
# ...
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_906_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_907_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_908_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_909_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_910_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_911_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_912_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_913_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_914_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_915_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_916_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_917_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_918_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_919_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_920_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_921_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_922_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_923_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_924_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_925_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_926_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_927_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_928_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_929_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_930_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_931_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_932_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_933_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_934_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_935_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_936_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_937_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_938_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_939_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_940_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_941_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_942_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_943_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_944_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_945_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_946_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_947_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_948_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_949_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_950_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_951_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_952_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_953_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_954_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_955_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_956_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_957_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_958_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_959_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_960_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_961_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_962_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_963_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_964_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_965_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_966_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_967_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_968_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_969_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_970_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_971_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_972_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_973_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_974_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_975_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_976_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_977_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_978_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_979_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_980_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_981_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_982_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_983_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_984_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_985_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_986_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_987_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_988_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_989_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_990_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_991_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_992_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_993_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_994_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_995_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_996_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_997_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_998_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_999_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_1000_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    ...}},
#  'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#  'updated_at': datetime.datetime(2024, 3, 25, 23, 17, 18, 598000)}

# %%
single_event_schema = {
    "id": "se_1",
    "timestamp": datetime.datetime.now(),
    "event_type": "interaction",
    "description": "This is an example description"
}

# Define the schema for VideoEvent
video_event_schema = {
    "recording_id": "vd_1",
    "lesson_id": "ls_1",
    "created_at": datetime.datetime.now(),
    "modified_at": datetime.datetime.now(),
    "events": {
        "event_1_id": single_event_schema,
    },
    "events_count": 1
}

transcript_data = [{
    "id": f"id_{i}",
    "video_id": "vd_1",
    "body": video_event_schema,
    "created_at": datetime.datetime.now(),
    "updated_at": datetime.datetime.now()
} for i in range(10000)]

# %% [markdown]
# ## 10,000 record insertion

# %%
import tqdm

# %%
t_start = datetime.datetime.now()
for _ in tqdm.tqdm(range(10000)):
    insert_video_transcript_record("vd_2", video_event_schema)
t_end = datetime.datetime.now()
print(f"Time taken to insert 1 records: {t_end - t_start}")
# Out:
#   4%|▍         | 444/10000 [00:18<06:35, 24.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 4
#       2 t_start = datetime.datetime.now()
#       3 for _ in tqdm.tqdm(range(10000)):
# ----> 4     insert_video_transcript_record("vd_2", video_event_schema)
#       5 t_end = datetime.datetime.now()
#       6 print(f"Time taken to insert 1 records: {t_end - t_start}")
#
# Cell In[19], line 44, in insert_video_transcript_record(video_id, body)
#      36 def insert_video_transcript_record(video_id, body):
#      37     new_record = {
#      38         "id": f"{ObjectId()}",
#      39         "video_id": video_id,
#    (...)
#      42         "updated_at": datetime.datetime.now()
#      43     }
# ---> 44     video_transcript.insert_one(new_record)
#      45     return new_record
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:597, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     594 if bypass_doc_val:
#     595     command["bypassDocumentValidation"] = True
# --> 597 result = conn.command(
#     598     self.__database.name,
#     599     command,
#     600     write_concern=write_concern,
#     601     codec_options=self.__write_response_codec_options,
#     602     session=session,
#     603     client=self.__database.client,
#     604     retryable_write=retryable_write,
#     605 )
#     607 _check_write_command_response(result)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/pool.py:996, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     994 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     995 except BaseException as error:
# --> 996     self._raise_connection_failure(error)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/network.py:182, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     180     response_doc: _DocumentOut = {"ok": 1}
#     181 else:
# --> 182     reply = receive_message(conn, request_id)
#     183     conn.more_to_come = reply.more_to_come
#     184     unpacked_docs = reply.unpack_response(
#     185         codec_options=codec_options, user_fields=user_fields
#     186     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# The time recorded is 667 records/sec
# The time recorded is 1287 records/sec
t_start = datetime.datetime.now()
video_transcript.insert_many(transcript_data)
t_end = datetime.datetime.now()
print(f"Time taken to insert 10000 records: {t_end - t_start}")
# Out:
# Time taken to insert 10000 records: 0:00:07.773325

# %% [markdown]
# ## Update Old Record to increment one event

# %%
def add_event_to_video_transcript(record, video_transcript_id, event):

    if record:
        # Append the new event to the events array
        record['body']['events'][f"event_{len(record['body']['events']) + 1}_id"] = event
        record['updated_at'] = datetime.datetime.now()

        # Update the document in the collection
        video_transcript.update_one({"id": video_transcript_id}, {"$set": record})
        return True
    else:
        print("Video transcript not found.")
        return False

# Example usage:
event = {
    "id": "se_2",
    "timestamp": datetime.datetime.now(),
    "event_type": "interaction",
    "description": "TuiNui"
}
# add_event_to_video_transcript("vt_1", event)

# %%
video_transcript.find({"id": "vt_1"}).next()
# Out:
# {'_id': ObjectId('6601a07857a2008af397cb69'),
#  'id': 'vt_1',
#  'video_id': 'vd_1',
#  'body': {'recording_id': 'vd_1',
#   'lesson_id': 'ls_1',
#   'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'modified_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'events': {'event_1_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_2_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_3_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_4_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_5_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 10, 38, 731000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_6_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_7_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_8_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_9_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_10_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_11_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_12_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_13_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_14_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_15_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_16_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_17_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_18_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_19_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_20_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_21_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_22_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_23_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_24_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_25_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_26_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_27_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_28_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_29_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_30_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_31_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_32_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_33_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_34_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_35_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_36_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_37_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_38_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_39_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_40_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_41_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_42_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_43_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_44_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_45_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_46_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_47_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_48_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_49_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_50_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_51_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_52_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_53_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_54_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_55_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_56_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_57_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_58_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_59_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_60_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_61_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_62_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_63_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_64_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_65_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_66_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_67_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_68_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_69_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_70_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_71_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_72_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_73_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_74_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_75_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_76_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_77_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_78_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_79_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_80_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_81_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_82_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_83_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_84_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_85_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_86_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_87_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_88_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_89_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_90_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_91_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_92_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_93_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_94_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_95_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_96_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_97_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_98_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_99_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_100_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_101_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_102_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_103_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_104_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_105_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_106_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_107_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_108_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_109_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_110_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_111_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_112_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_113_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_114_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_115_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_116_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_117_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_118_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_119_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_120_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_121_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_122_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_123_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_124_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_125_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_126_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_127_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_128_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_129_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_130_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_131_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_132_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_133_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_134_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_135_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_136_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_137_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_138_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_139_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_140_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_141_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_142_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_143_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_144_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_145_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_146_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_147_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_148_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_149_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_150_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_151_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_152_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_153_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_154_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_155_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_156_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_157_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_158_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_159_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_160_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_161_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_162_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_163_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_164_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_165_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_166_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_167_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_168_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_169_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_170_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_171_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_172_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_173_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_174_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_175_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_176_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_177_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_178_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_179_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_180_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_181_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_182_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_183_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_184_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_185_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_186_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_187_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_188_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_189_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_190_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_191_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_192_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_193_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_194_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_195_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_196_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_197_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_198_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_199_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_200_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_201_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_202_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_203_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_204_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_205_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_206_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_207_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_208_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_209_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_210_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_211_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_212_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_213_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_214_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_215_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_216_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_217_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_218_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_219_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_220_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_221_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_222_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_223_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_224_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_225_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_226_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_227_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_228_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_229_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_230_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_231_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_232_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_233_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_234_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_235_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_236_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_237_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_238_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_239_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_240_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_241_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_242_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_243_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_244_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_245_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_246_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_247_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_248_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_249_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_250_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_251_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_252_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_253_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_254_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_255_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_256_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_257_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_258_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_259_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_260_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_261_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_262_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_263_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_264_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_265_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_266_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_267_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_268_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_269_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_270_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_271_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_272_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_273_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_274_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_275_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_276_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_277_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_278_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_279_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_280_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_281_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_282_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_283_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_284_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_285_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_286_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_287_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_288_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
# ...
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_906_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_907_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_908_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_909_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_910_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_911_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_912_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_913_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_914_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_915_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_916_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_917_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_918_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_919_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_920_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_921_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_922_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_923_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_924_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_925_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_926_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_927_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_928_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_929_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_930_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_931_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_932_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_933_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_934_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_935_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_936_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_937_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_938_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_939_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_940_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_941_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_942_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_943_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_944_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_945_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_946_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_947_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_948_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_949_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_950_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_951_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_952_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_953_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_954_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_955_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_956_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_957_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_958_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_959_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_960_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_961_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_962_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_963_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_964_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_965_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_966_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_967_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_968_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_969_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_970_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_971_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_972_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_973_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_974_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_975_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_976_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_977_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_978_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_979_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_980_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_981_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_982_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_983_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_984_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_985_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_986_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_987_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_988_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_989_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_990_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_991_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_992_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_993_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_994_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_995_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_996_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_997_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_998_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_999_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    'event_1000_id': {'id': 'se_2',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 13, 40, 261000),
#     'event_type': 'interaction',
#     'description': 'TuiNui'},
#    ...}},
#  'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#  'updated_at': datetime.datetime(2024, 3, 25, 23, 17, 18, 598000)}

# %%
def add_event_to_video_transcript_check_max_event(record, video_transcript_id, event_id, event):
    video_event = record['body']
    
    if video_event['events_count'] < 200:
        # Append the new event to the events array
        video_event['events'][event_id] = event
        video_event['events_count'] += 1

        # Update the document in the collection
        video_transcript.update_one({"id": video_transcript_id}, {"$set": {'body': video_event}})
        return True
    else:
        print('Maximun Event Reached')
        return False

# Example usage:
event = {
    "id": "se_2",
    "timestamp": datetime.datetime.now(),
    "event_type": "interaction",
    "description": "TuiNui"
}
# add_event_to_video_transcript("vt_1", event)

# %% [markdown]
# # Update Performace Test

# %%
events_to_update = {f"event_{i + 2}_id": {
                                            "id": "se_2",
                                            "timestamp": datetime.datetime.now(),
                                            "event_type": "interaction",
                                            "description": "TuiNui"
                                        } for i in range(200)}

transcript_ids = [f"id_{i}" for i in range(50)]

# %%
video_transcript = db.VideoTranscript
# Retrieve the existing video_transcript document
t_start = datetime.datetime.now()

for transcript_id in transcript_ids:
    record = video_transcript.find_one({"id": transcript_id})

    for event_id, event in events_to_update.items():
        add_event_to_video_transcript_check_max_event(record, transcript_id, event_id, event)
    
    print(transcript_id)

t_end = datetime.datetime.now()
print(f"Time taken to insert 1000 records: {t_end - t_start}")
# 6-7 iterations per second
# Out:
# Maximun Event Reached
# id_0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 9
#       6     record = video_transcript.find_one({"id": transcript_id})
#       8     for event_id, event in events_to_update.items():
# ----> 9         add_event_to_video_transcript_check_max_event(record, transcript_id, event_id, event)
#      11     print(transcript_id)
#      13 t_end = datetime.datetime.now()
#
# Cell In[39], line 10, in add_event_to_video_transcript_check_max_event(record, video_transcript_id, event_id, event)
#       7     video_event['events_count'] += 1
#       9     # Update the document in the collection
# ---> 10     video_transcript.update_one({"id": video_transcript_id}, {"$set": {'body': video_event}})
#      11     return True
#      12 else:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:1086, in Collection.update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session, let, comment)
#    1082 common.validate_list_or_none("array_filters", array_filters)
#    1084 write_concern = self._write_concern_for(session)
#    1085 return UpdateResult(
# -> 1086     self._update_retryable(
#    1087         filter,
#    1088         update,
#    1089         upsert,
#    1090         write_concern=write_concern,
#    1091         bypass_doc_val=bypass_document_validation,
#    1092         collation=collation,
#    1093         array_filters=array_filters,
#    1094         hint=hint,
#    1095         session=session,
#    1096         let=let,
#    1097         comment=comment,
#    1098     ),
#    1099     write_concern.acknowledged,
#    1100 )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:881, in Collection._update_retryable(self, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, comment)
#     859 def _update(
#     860     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#     861 ) -> Optional[Mapping[str, Any]]:
#     862     return self._update(
#     863         conn,
#     864         criteria,
#    (...)
#     878         comment=comment,
#     879     )
# --> 881 return self.__database.client._retryable_write(
#     882     (write_concern or self.write_concern).acknowledged and not multi, _update, session
#     883 )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:862, in Collection._update_retryable.<locals>._update(session, conn, retryable_write)
#     859 def _update(
#     860     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#     861 ) -> Optional[Mapping[str, Any]]:
# --> 862     return self._update(
#     863         conn,
#     864         criteria,
#     865         document,
#     866         upsert=upsert,
#     867         multi=multi,
#     868         write_concern=write_concern,
#     869         op_id=op_id,
#     870         ordered=ordered,
#     871         bypass_doc_val=bypass_doc_val,
#     872         collation=collation,
#     873         array_filters=array_filters,
#     874         hint=hint,
#     875         session=session,
#     876         retryable_write=retryable_write,
#     877         let=let,
#     878         comment=comment,
#     879     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/collection.py:816, in Collection._update(self, conn, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write, let, comment)
#     812     command["bypassDocumentValidation"] = True
#     814 # The command result has to be published for APM unmodified
#     815 # so we make a shallow copy here before adding updatedExisting.
# --> 816 result = conn.command(
#     817     self.__database.name,
#     818     command,
#     819     write_concern=write_concern,
#     820     codec_options=self.__write_response_codec_options,
#     821     session=session,
#     822     client=self.__database.client,
#     823     retryable_write=retryable_write,
#     824 ).copy()
#     825 _check_write_command_response(result)
#     826 # Add the updatedExisting field for compatibility.
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/pool.py:996, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     994 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     995 except BaseException as error:
# --> 996     self._raise_connection_failure(error)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/network.py:182, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     180     response_doc: _DocumentOut = {"ok": 1}
#     181 else:
# --> 182     reply = receive_message(conn, request_id)
#     183     conn.more_to_come = reply.more_to_come
#     184     unpacked_docs = reply.unpack_response(
#     185         codec_options=codec_options, user_fields=user_fields
#     186     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
video_transcript.find_one({"id": "id_2"})
# Out:
# {'_id': ObjectId('66058c40a5f28dacd3a5370a'),
#  'id': 'id_2',
#  'video_id': 'vd_1',
#  'body': {'recording_id': 'vd_1',
#   'lesson_id': 'ls_1',
#   'created_at': datetime.datetime(2024, 3, 28, 22, 26, 43, 215000),
#   'modified_at': datetime.datetime(2024, 3, 28, 22, 26, 43, 215000),
#   'events': {'event_1_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 28, 22, 26, 43, 215000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'}}},
#  'created_at': datetime.datetime(2024, 3, 28, 22, 26, 43, 215000),
#  'updated_at': datetime.datetime(2024, 3, 28, 22, 26, 43, 215000)}

# %% [markdown]
# # Delete all records

# %%
video_transcript.delete_many({})
# Out:
# DeleteResult({'n': 10000, 'electionId': ObjectId('7fffffff00000000000000d0'), 'opTime': {'ts': Timestamp(1711645355, 414), 't': 208}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1711645355, 430), 'signature': {'hash': b'\xecU\x0fa\x9aj\x1f\xf22\x1e\x1a\xc0\x9b\xf4\xd8.\x18\xeb\x9d\xea', 'keyId': 7306530997393162245}}, 'operationTime': Timestamp(1711645355, 414)}, acknowledged=True)

# %%
# Close MongoDB connection
client.close()
