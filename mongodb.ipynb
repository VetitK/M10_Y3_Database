# %%
#############Connecting
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
# import ObjectId
from bson import ObjectId
import datetime
uri = "mongodb+srv://mongoAdmin:ESiN65ToylzRhOis@cluster0.deup10k.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
##############QUERYING
db = client.sample_mflix
print(db.list_collection_names())

movies = db['movies']
res= movies.find().limit(10)
for m in res:
    print(m)
print('-----------------')
movies = db['comments']
res= movies.find().limit(10)
for m in res:
    print(m)
# Out:
# ['movies', 'theaters', 'sessions', 'users', 'comments', 'embedded_movies']
# ...

# %%
###############INSERT NEW VALUES

{'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': ObjectId('573a1390f29313caabcd4323'), 'text': 'Really great movie', 'date': datetime.datetime(2024, 3, 21, 4, 56, 7)}

comments = db['comments']
comments.insert_one({'name': 'MyDiffName', 'email': 'yaour@fakegmail.com', 'movie_id': {"$oid":'573a1390f29313caabcd4323'}, 'text': 'Really great movie', "date":{"$date":{"$numberLong":"1029646567000"}}}
)
# Out:
# InsertOneResult(ObjectId('660196ae57a2008af397c63d'), acknowledged=True)

# %%
########### FINDING YOUR DATE

res= comments.find({'name': 'MyName'})
for m in res:
    print(m)


############################
# Out:
# {'_id': ObjectId('65fbae4915e1ca5bf2b99b1b'), 'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': {'$oid': '573a1390f29313caabcd4323'}, 'text': 'Really great movie', 'date': {'$date': {'$numberLong': '1029646567000'}}}
# {'_id': ObjectId('65fbaf5315e1ca5bf2b99b1c'), 'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': {'$oid': '573a1390f29313caabcd4323'}, 'text': 'Really great movie', 'date': {'$date': {'$numberLong': '1029646567000'}}}
# {'_id': ObjectId('65fbaf5d15e1ca5bf2b99b1d'), 'name': 'MyName', 'email': 'yaour@fakegmail.com', 'movie_id': {'$oid': '573a1390f29313caabcd4323'}, 'text': 'Really great movie', 'date': {'$date': {'$numberLong': '1029646567000'}}}
# ['sell_stock_request', 'default', 'new_collection', 'test', 'comments']

# %% [markdown]
# # Connect to our DB

# %%
db = client.locth
db.list_collection_names()
# Out:
# ['default', 'VideoTranscript']

# %% [markdown]
# ## Create collection: VideoTranscript

# %%
video_transcript = db.create_collection('VideoTranscript')
# Out:
# ---------------------------------------------------------------------------
# CollectionInvalid                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 video_transcript = db.create_collection('VideoTranscript')
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/pymongo/database.py:467, in Database.create_collection(self, name, codec_options, read_preference, write_concern, read_concern, session, check_exists, **kwargs)
#     459 with self.__client._tmp_session(session) as s:
#     460     # Skip this check in a transaction where listCollections is not
#     461     # supported.
#     462     if (
#     463         check_exists
# ...

# %%
db.list_collection_names()
# Out:
# ['default', 'VideoTranscript']

# %% [markdown]
# ## The schema for VideoTranscript is as follows:

# %%
# Define the schema for SingleEvent
single_event_schema = {
    "id": "se_1",
    "timestamp": datetime.datetime.now(),
    "event_type": "interaction",
    "description": "This is an example description"
}

# Define the schema for VideoEvent
video_event_schema = {
    "recording_id": "vd_1",
    "lesson_id": "ls_1",
    "created_at": datetime.datetime.now(),
    "modified_at": datetime.datetime.now(),
    "events": {
        "event_1_id": single_event_schema,
        "event_2_id": single_event_schema,
        "event_3_id": single_event_schema,
        "event_4_id": single_event_schema
    }
}

# Define the schema for VideoTranscript
video_transcript_schema = {
    "id": "vt_1",
    "video_id": "vd_1",
    "body": video_event_schema,
    "created_at": datetime.datetime.now(),
    "updated_at": datetime.datetime.now()
}

# Insert sample data into the collection
video_transcript.insert_one(video_transcript_schema)

# Define function to insert new records into VideoTranscript collection
def insert_video_transcript_record(video_id, body):
    new_record = {
        "id": f"vt_{video_transcript.count_documents({}) + 1}",
        "video_id": video_id,
        "body": body,
        "created_at": datetime.datetime.now(),
        "updated_at": datetime.datetime.now()
    }
    video_transcript.insert_one(new_record)
    return new_record

# Example usage:
new_video_transcript_record = insert_video_transcript_record("vd_2", video_event_schema)
print(new_video_transcript_record)
# Out:
# {'id': 'vt_2', 'video_id': 'vd_2', 'body': {'recording_id': 'vd_1', 'lesson_id': 'ls_1', 'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3460), 'modified_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3461), 'events': {'event_1_id': {'id': 'se_1', 'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3419), 'event_type': 'interaction', 'description': 'This is an example description'}, 'event_2_id': {'id': 'se_1', 'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3419), 'event_type': 'interaction', 'description': 'This is an example description'}, 'event_3_id': {'id': 'se_1', 'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3419), 'event_type': 'interaction', 'description': 'This is an example description'}, 'event_4_id': {'id': 'se_1', 'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3419), 'event_type': 'interaction', 'description': 'This is an example description'}}}, 'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 127784), 'updated_at': datetime.datetime
# ...

# %%
video_transcript.find({"id": "vt_1"}).next()
# Out:
# {'_id': ObjectId('6601a07857a2008af397cb69'),
#  'id': 'vt_1',
#  'video_id': 'vd_1',
#  'body': {'recording_id': 'vd_1',
#   'lesson_id': 'ls_1',
#   'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'modified_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'events': {'event_1_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_2_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_3_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_4_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
# ...

# %% [markdown]
# ## 10,000 record insertion

# %%
for _ in range(1000):
    t_start = datetime.datetime.now()
    insert_video_transcript_record("vd_2", video_event_schema)
    t_end = datetime.datetime.now()
    print(f"Time taken to insert 1 records: {t_end - t_start}")
# Out:
# Time taken to insert 1 records: 0:00:00.107875
# Time taken to insert 1 records: 0:00:00.104318
# Time taken to insert 1 records: 0:00:00.110465
# Time taken to insert 1 records: 0:00:00.120671
# Time taken to insert 1 records: 0:00:00.138989
# Time taken to insert 1 records: 0:00:00.115272
# Time taken to insert 1 records: 0:00:00.120987
# Time taken to insert 1 records: 0:00:00.169415
# Time taken to insert 1 records: 0:00:00.118865
# Time taken to insert 1 records: 0:00:00.145927
# Time taken to insert 1 records: 0:00:00.120329
# Time taken to insert 1 records: 0:00:00.119184
# Time taken to insert 1 records: 0:00:00.109109
# Time taken to insert 1 records: 0:00:00.135551
# Time taken to insert 1 records: 0:00:00.123489
# Time taken to insert 1 records: 0:00:00.130078
# Time taken to insert 1 records: 0:00:00.121221
# Time taken to insert 1 records: 0:00:00.125651
# Time taken to insert 1 records: 0:00:00.114469
# Time taken to insert 1 records: 0:00:00.114370
# ...

# %% [markdown]
# ## Update Old Record to increment one event

# %%
def add_event_to_video_transcript(video_transcript_id, event):
    # Retrieve the existing video_transcript document
    record = video_transcript.find_one({"id": video_transcript_id})

    if record:
        # Append the new event to the events array
        record['body']['events'][f"event_{len(record['body']['events']) + 1}_id"] = event
        record['updated_at'] = datetime.datetime.now()

        # Update the document in the collection
        video_transcript.update_one({"id": video_transcript_id}, {"$set": record})
        return True
    else:
        print("Video transcript not found.")
        return False

# Example usage:
event = {
    "id": "se_2",
    "timestamp": datetime.datetime.now(),
    "event_type": "interaction",
    "description": "TuiNui"
}
add_event_to_video_transcript("vt_1", event)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 24
#      17 # Example usage:
#      18 event = {
#      19     "id": "se_2",
#      20     "timestamp": datetime.datetime.now(),
#      21     "event_type": "interaction",
#      22     "description": "TuiNui"
#      23 }
# ---> 24 add_event_to_video_transcript("vt_1", event)
#
# Cell In[5], line 3, in add_event_to_video_transcript(video_transcript_id, event)
#       1 def add_event_to_video_transcript(video_transcript_id, event):
#       2     # Retrieve the existing video_transcript document
# ----> 3     record = video_transcript.find_one({"id": video_transcript_id})
#       5     if record:
#       6         # Append the new event to the events array
#       7         record['body']['events'][f"event_{len(record['body']['events']) + 1}_id"] = event
#
# NameError: name 'video_transcript' is not defined

# %%
video_transcript.find({"id": "vt_1"}).next()
# Out:
# {'_id': ObjectId('6601a07857a2008af397cb6a'),
#  'id': 'vt_2',
#  'video_id': 'vd_2',
#  'body': {'recording_id': 'vd_1',
#   'lesson_id': 'ls_1',
#   'created_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'modified_at': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#   'events': {'event_1_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_2_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_3_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
#     'event_type': 'interaction',
#     'description': 'This is an example description'},
#    'event_4_id': {'id': 'se_1',
#     'timestamp': datetime.datetime(2024, 3, 25, 23, 4, 8, 3000),
# ...

# %% [markdown]
# # Update Performace Test

# %%
import tqdm
video_transcript = db.VideoTranscript
t_start = datetime.datetime.now()
for _ in tqdm.tqdm(range(1000)):
    add_event_to_video_transcript("vt_1", event)
t_end = datetime.datetime.now()
print(f"Time taken to insert 1000 records: {t_end - t_start}")
# 6-7 iterations per second
# Out:
# 100%|██████████| 1000/1000 [03:12<00:00,  5.20it/s]
# Time taken to insert 1000 records: 0:03:12.414913

# %% [markdown]
# # Delete all records

# %%
video_transcript.delete_many({})
# Out:
# DeleteResult({'n': 1323, 'electionId': ObjectId('7fffffff00000000000000d0'), 'opTime': {'ts': Timestamp(1711382587, 1325), 't': 208}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1711382587, 1327), 'signature': {'hash': b'\xf7\x01DNh\x8a"\x92)\xdfe;\x8aY\x07!\xf6\xba\xabv', 'keyId': 7306530997393162245}}, 'operationTime': Timestamp(1711382587, 1325)}, acknowledged=True)

# %%
# Close MongoDB connection
client.close()
