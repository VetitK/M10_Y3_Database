# %%
import psycopg2

from datetime import datetime
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ForeignKey, DateTime, Float
from sqlalchemy.orm import sessionmaker, declarative_base

# %% [markdown]
# # Create Table Strucuture

# %%
def connect():
   conn = psycopg2.connect(database="postgres",
                           user="locthadmin",
                           password="password",
                        host="database-1.c32ikym4q9dx.ap-southeast-1.rds.amazonaws.com",
                           port="5432",
                           options="-c search_path=locth")
   return conn

# %%
def delete_tables(table_names):
    conn = connect()
    cur = conn.cursor()

    for name in table_names:
        cur.execute(f'DROP TABLE {name} CASCADE;')

    conn.commit()
    conn.close()

# %%
engine = create_engine('postgresql+psycopg2://locthadmin:password@database-1.c32ikym4q9dx.ap-southeast-1.rds.amazonaws.com/postgres', echo=True, connect_args={'options': '-csearch_path={}'.format('locth')})
Base = declarative_base()

# %%
class Teacher(Base):
    __tablename__ = 'teacher'    
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    name = Column(String)
    surname = Column(String)
    email = Column(String)    
    # Defines to_string() representation 
    def __repr__(self):
        return f"<Teacher(name={self.name}, surname={self.surname}, email={self.email})>"

class Student(Base):
    __tablename__ = 'student'    
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    name = Column(String)
    surname = Column(String)
    email = Column(String)
    birthdate = Column(DateTime)
    address = Column(String)    
    # Defines to_string() representation 
    def __repr__(self):
        return f"<Student(name={self.name}, surname={self.surname}, email={self.email}), birthdate={self.birthdate}, address={self.address}>"

class Course(Base):
    __tablename__ = 'course'    
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    name = Column(String)
    description = Column(String)
    program = Column(String) # Python, C++, Java, etc.
    level = Column(Integer) # 1, 2, 3, 4
    # Defines to_string() representation 
    def __repr__(self):
        return f"<Course(name={self.name}, description={self.description}, teacher_id={self.teacher_id})>"

class CourseInstance(Base):
    __tablename__ = 'course_instance'
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    start_date = Column(DateTime)
    end_date = Column(DateTime)
    base_price = Column(Float)
    course_id = Column(Integer, ForeignKey('course.id'))
    teacher_id = Column(Integer, ForeignKey('teacher.id'))
    format = Column(String) # Online, In-person, Hybrid
    course_type = Column(String) # Camp, Live class, 1on1
    # Defines to_string() representation
    def __repr__(self):
        return f"<CourseInstance(start_date={self.start_date}, end_date={self.end_date}, base_price={self.base_price}, course_id={self.course_id}, teacher_id={self.teacher_id}, format={self.format}, course_type={self.course_type})>"    

class Purchase(Base):
    __tablename__ = 'purchase'
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    purchase_date = Column(DateTime)
    amount = Column(Float)
    student_id = Column(Integer, ForeignKey('student.id'))
    course_instance_id = Column(Integer, ForeignKey('course_instance.id'))
    # Defines to_string() representation
    def __repr__(self):
        return f"<Purchase(purchase_date={self.purchase_date}, amount={self.amount}, student_id={self.student_id}, course_instance_id={self.course_instance_id})>"

class StudentCourse(Base):
    __tablename__ = 'student_course'
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    student_id = Column(Integer, ForeignKey('student.id'))
    course_instance_id = Column(Integer, ForeignKey('course_instance.id'))
    status = Column(String) # Enrolled, Completed, Dropped, etc.
    # Defines to_string() representation
    def __repr__(self):
        return f"<StudentCourse(student_id={self.student_id}, course_instance_id={self.course_instance_id})>"

class Lesson(Base):
    __tablename__ = 'lesson'
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    session_number = Column(Integer) # 1,2,3,4
    course_instance_id = Column(Integer, ForeignKey('course_instance.id'))
    date = Column(DateTime)
    recording_url = Column(String)
    # Defines to_string() representation
    def __repr__(self):
        return f"<Lesson(session_number={self.session_number}, course_instance_id={self.course_instance_id}, date={self.date}, recording_url={self.recording_url})>"

class Certificate(Base):
    __tablename__ = 'certificate'
    id = Column(Integer, primary_key=True, unique=True, autoincrement=True, nullable=False, index=True,)
    student_id = Column(Integer, ForeignKey('student.id'))
    course_instance_id = Column(Integer, ForeignKey('course_instance.id'))
    issue_date = Column(DateTime)
    url = Column(String)
    # Defines to_string() representation
    def __repr__(self):
        return f"<Certificate(student_id={self.student_id}, course_instance_id={self.course_instance_id}, issue_date={self.issue_date}, url={self.url})>"
    
def construct_database(engine):
    Base.metadata.create_all(engine)

# %%
construct_database(engine)
# Out:
# 2024-03-17 15:45:41,323 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-03-17 15:45:41,324 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-03-17 15:45:41,717 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-03-17 15:45:41,717 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-03-17 15:45:41,810 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-03-17 15:45:41,811 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-03-17 15:45:41,920 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:45:41,924 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:41,925 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,037 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,038 INFO sqlalchemy.engine.Engine [cached since 0.1134s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,106 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,107 INFO sqlalchemy.engine.Engine [cached since 0.1833s ago] {'table_name': 'course', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,157 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,158 INFO sqlalchemy.engine.Engine [cached since 0.234s ago] {'table_name': 'course_instance', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,215 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,216 INFO sqlalchemy.engine.Engine [cached since 0.2918s ago] {'table_name': 'purchase', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,287 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,288 INFO sqlalchemy.engine.Engine [cached since 0.3637s ago] {'table_name': 'student_course', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,379 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,380 INFO sqlalchemy.engine.Engine [cached since 0.456s ago] {'table_name': 'lesson', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,435 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-03-17 15:45:42,436 INFO sqlalchemy.engine.Engine [cached since 0.5114s ago] {'table_name': 'certificate', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-03-17 15:45:42,488 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	id SERIAL NOT NULL,
# 	name VARCHAR,
# 	surname VARCHAR,
# 	email VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2024-03-17 15:45:42,489 INFO sqlalchemy.engine.Engine [no key 0.00057s] {}
# 2024-03-17 15:45:42,544 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_teacher_id ON teacher (id)
# 2024-03-17 15:45:42,545 INFO sqlalchemy.engine.Engine [no key 0.00061s] {}
# 2024-03-17 15:45:42,595 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	id SERIAL NOT NULL,
# 	name VARCHAR,
# 	surname VARCHAR,
# 	email VARCHAR,
# 	birthdate TIMESTAMP WITHOUT TIME ZONE,
# 	address VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2024-03-17 15:45:42,595 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2024-03-17 15:45:42,657 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_student_id ON student (id)
# 2024-03-17 15:45:42,658 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2024-03-17 15:45:42,768 INFO sqlalchemy.engine.Engine
# CREATE TABLE course (
# 	id SERIAL NOT NULL,
# 	name VARCHAR,
# 	description VARCHAR,
# 	program VARCHAR,
# 	level INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2024-03-17 15:45:42,769 INFO sqlalchemy.engine.Engine [no key 0.00102s] {}
# 2024-03-17 15:45:42,835 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_course_id ON course (id)
# 2024-03-17 15:45:42,835 INFO sqlalchemy.engine.Engine [no key 0.00055s] {}
# 2024-03-17 15:45:42,893 INFO sqlalchemy.engine.Engine
# CREATE TABLE course_instance (
# 	id SERIAL NOT NULL,
# 	start_date TIMESTAMP WITHOUT TIME ZONE,
# 	end_date TIMESTAMP WITHOUT TIME ZONE,
# 	base_price FLOAT,
# 	course_id INTEGER,
# 	teacher_id INTEGER,
# 	format VARCHAR,
# 	course_type VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(course_id) REFERENCES course (id),
# 	FOREIGN KEY(teacher_id) REFERENCES teacher (id)
# )
#
#
# 2024-03-17 15:45:42,894 INFO sqlalchemy.engine.Engine [no key 0.00078s] {}
# 2024-03-17 15:45:42,953 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_course_instance_id ON course_instance (id)
# 2024-03-17 15:45:42,953 INFO sqlalchemy.engine.Engine [no key 0.00056s] {}
# 2024-03-17 15:45:42,998 INFO sqlalchemy.engine.Engine
# CREATE TABLE purchase (
# 	id SERIAL NOT NULL,
# 	purchase_date TIMESTAMP WITHOUT TIME ZONE,
# 	amount FLOAT,
# 	student_id INTEGER,
# 	course_instance_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(student_id) REFERENCES student (id),
# 	FOREIGN KEY(course_instance_id) REFERENCES course_instance (id)
# )
#
#
# 2024-03-17 15:45:42,999 INFO sqlalchemy.engine.Engine [no key 0.00064s] {}
# 2024-03-17 15:45:43,063 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_purchase_id ON purchase (id)
# 2024-03-17 15:45:43,064 INFO sqlalchemy.engine.Engine [no key 0.00054s] {}
# 2024-03-17 15:45:43,126 INFO sqlalchemy.engine.Engine
# CREATE TABLE student_course (
# 	id SERIAL NOT NULL,
# 	student_id INTEGER,
# 	course_instance_id INTEGER,
# 	status VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(student_id) REFERENCES student (id),
# 	FOREIGN KEY(course_instance_id) REFERENCES course_instance (id)
# )
#
#
# 2024-03-17 15:45:43,126 INFO sqlalchemy.engine.Engine [no key 0.00054s] {}
# 2024-03-17 15:45:43,187 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_student_course_id ON student_course (id)
# 2024-03-17 15:45:43,188 INFO sqlalchemy.engine.Engine [no key 0.00058s] {}
# 2024-03-17 15:45:43,238 INFO sqlalchemy.engine.Engine
# CREATE TABLE lesson (
# 	id SERIAL NOT NULL,
# 	session_number INTEGER,
# 	course_instance_id INTEGER,
# 	date TIMESTAMP WITHOUT TIME ZONE,
# 	recording_url VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(course_instance_id) REFERENCES course_instance (id)
# )
#
#
# 2024-03-17 15:45:43,238 INFO sqlalchemy.engine.Engine [no key 0.00058s] {}
# 2024-03-17 15:45:43,382 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_lesson_id ON lesson (id)
# 2024-03-17 15:45:43,383 INFO sqlalchemy.engine.Engine [no key 0.00082s] {}
# 2024-03-17 15:45:43,564 INFO sqlalchemy.engine.Engine
# CREATE TABLE certificate (
# 	id SERIAL NOT NULL,
# 	student_id INTEGER,
# 	course_instance_id INTEGER,
# 	issue_date TIMESTAMP WITHOUT TIME ZONE,
# 	url VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(student_id) REFERENCES student (id),
# 	FOREIGN KEY(course_instance_id) REFERENCES course_instance (id)
# )
#
#
# 2024-03-17 15:45:43,565 INFO sqlalchemy.engine.Engine [no key 0.00098s] {}
# 2024-03-17 15:45:43,618 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_certificate_id ON certificate (id)
# 2024-03-17 15:45:43,619 INFO sqlalchemy.engine.Engine [no key 0.00087s] {}
# 2024-03-17 15:45:43,674 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# # Populate Tables

# %%
Session = sessionmaker(bind=engine)
session = Session()

def populate_data_1():
# Sample data for each table
    teachers_data = [
        {"name": "John", "surname": "Doe", "email": "john.doe@example.com"},
        {"name": "Alice", "surname": "Smith", "email": "alice.smith@example.com"},
        {"name": "Michael", "surname": "Johnson", "email": "michael.j@example.com"},
        {"name": "Emily", "surname": "Brown", "email": "emily.b@example.com"},
        {"name": "David", "surname": "Miller", "email": "david.m@example.com"}
    ]

    students_data = [
        {"name": "Sarah", "surname": "Adams", "email": "sarah.a@example.com", "birthdate": datetime(1998, 5, 15), "address": "123 Elm St, Anytown"},
        {"name": "James", "surname": "Wilson", "email": "james.w@example.com", "birthdate": datetime(1999, 8, 20), "address": "456 Oak St, Othertown"},
        {"name": "Emma", "surname": "Lee", "email": "emma.l@example.com", "birthdate": datetime(2000, 3, 10), "address": "789 Maple Ave, Anycity"},
        {"name": "Ethan", "surname": "Taylor", "email": "ethan.t@example.com", "birthdate": datetime(1997, 11, 30), "address": "101 Pine St, Somewhere"},
        {"name": "Olivia", "surname": "Wright", "email": "olivia.w@example.com", "birthdate": datetime(1996, 2, 25), "address": "222 Cedar St, Nowhere"}
    ]

    courses_data = [
        {"name": "Python Basics", "description": "Introduction to Python", "program": "Python", "level": 1},
        {"name": "Java Fundamentals", "description": "Introduction to Java", "program": "Java", "level": 1},
        {"name": "Advanced Python", "description": "Advanced Python topics", "program": "Python", "level": 2},
        {"name": "C++ Programming", "description": "Introduction to C++", "program": "C++", "level": 1},
        {"name": "Web Development", "description": "HTML, CSS, JavaScript", "program": "Web Dev", "level": 1}
    ]

    # # Populate tables
    for teacher_data in teachers_data:
        teacher = Teacher(**teacher_data)
        session.add(teacher)

    for student_data in students_data:
        student = Student(**student_data)
        session.add(student)

    for course_data in courses_data:
        course = Course(**course_data)
        session.add(course)

    # Commit the changes
    session.commit()
    
def populate_data_2():
# Sample data for each table

    course_instances_data = [
        {"start_date": datetime(2024, 4, 1, 10, 0), "end_date": datetime(2024, 6, 30, 15, 0), "base_price": 200.00, "course_id": 1, "teacher_id": 1, "format": "Online", "course_type": "Live class"},
        {"start_date": datetime(2024, 5, 10, 9, 0), "end_date": datetime(2024, 8, 20, 12, 0), "base_price": 250.00, "course_id": 2, "teacher_id": 2, "format": "In-person", "course_type": "Camp"},
        {"start_date": datetime(2024, 6, 15, 13, 0), "end_date": datetime(2024, 9, 30, 18, 0), "base_price": 300.00, "course_id": 3, "teacher_id": 3, "format": "Hybrid", "course_type": "1on1"},
        {"start_date": datetime(2024, 7, 20, 11, 0), "end_date": datetime(2024, 10, 25, 16, 0), "base_price": 220.00, "course_id": 4, "teacher_id": 4, "format": "Online", "course_type": "Live class"},
        {"start_date": datetime(2024, 8, 5, 10, 0), "end_date": datetime(2024, 11, 15, 14, 0), "base_price": 270.00, "course_id": 5, "teacher_id": 5, "format": "In-person", "course_type": "Camp"}
    ]
    # Populate tables

    for course_instance_data in course_instances_data:
        course_instance = CourseInstance(**course_instance_data)
        session.add(course_instance)

    # Commit the changes
    session.commit()

def populate_data_3():
# Sample data for each table


    purchases_data = [
        {"purchase_date": datetime(2024, 4, 2, 8, 30), "amount": 200.00, "student_id": 1, "course_instance_id": 1},
        {"purchase_date": datetime(2024, 5, 15, 11, 45), "amount": 250.00, "student_id": 2, "course_instance_id": 2},
        {"purchase_date": datetime(2024, 6, 20, 14, 20), "amount": 300.00, "student_id": 3, "course_instance_id": 3},
        {"purchase_date": datetime(2024, 7, 25, 9, 0), "amount": 220.00, "student_id": 4, "course_instance_id": 4},
        {"purchase_date": datetime(2024, 8, 6, 12, 10), "amount": 270.00, "student_id": 5, "course_instance_id": 5}
    ]

    student_courses_data = [
        {"student_id": 1, "course_instance_id": 1, "status": "Enrolled"},
        {"student_id": 2, "course_instance_id": 2, "status": "Enrolled"},
        {"student_id": 3, "course_instance_id": 3, "status": "Enrolled"},
        {"student_id": 4, "course_instance_id": 4, "status": "Enrolled"},
        {"student_id": 5, "course_instance_id": 5, "status": "Enrolled"}
    ]

    lessons_data = [
        {"session_number": 1, "course_instance_id": 1, "date": datetime(2024, 4, 5, 10, 0), "recording_url": "https://example.com/1"},
        {"session_number": 1, "course_instance_id": 2, "date": datetime(2024, 5, 12, 9, 0), "recording_url": "https://example.com/2"},
        {"session_number": 1, "course_instance_id": 3, "date": datetime(2024, 6, 17, 13, 0), "recording_url": "https://example.com/3"},
        {"session_number": 1, "course_instance_id": 4, "date": datetime(2024, 7, 22, 11, 0), "recording_url": "https://example.com/4"},
        {"session_number": 1, "course_instance_id": 5, "date": datetime(2024, 8, 7, 10, 0), "recording_url": "https://example.com/5"}
    ]

    certificates_data = [
        {"student_id": 1, "course_instance_id": 1, "issue_date": datetime(2024, 6, 30, 15, 0), "url": "https://example.com/1"},
        {"student_id": 2, "course_instance_id": 2, "issue_date": datetime(2024, 8, 20, 12, 0), "url": "https://example.com/2"},
        {"student_id": 3, "course_instance_id": 3, "issue_date": datetime(2024, 9, 30, 18, 0), "url": "https://example.com/3"},
        {"student_id": 4, "course_instance_id": 4, "issue_date": datetime(2024, 10, 25, 16, 0), "url": "https://example.com/4"},
        {"student_id": 5, "course_instance_id": 5, "issue_date": datetime(2024, 11, 15, 14, 0), "url": "https://example.com/5"}
    ]

    # Populate tables


    for purchase_data in purchases_data:
        purchase = Purchase(**purchase_data)
        session.add(purchase)

    for student_course_data in student_courses_data:
        student_course = StudentCourse(**student_course_data)
        session.add(student_course)

    for lesson_data in lessons_data:
        lesson = Lesson(**lesson_data)
        session.add(lesson)

    for certificate_data in certificates_data:
        certificate = Certificate(**certificate_data)
        session.add(certificate)

    # Commit the changes
    session.commit()

populate_data_1()
populate_data_2()
populate_data_3()
# Out:
# 2024-03-17 15:45:54,949 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:45:54,951 INFO sqlalchemy.engine.Engine INSERT INTO course (name, description, program, level) SELECT p0::VARCHAR, p1::VARCHAR, p2::VARCHAR, p3::INTEGER FROM (VALUES (%(name__0)s, %(description__0)s, %(program__0)s, %(level__0)s, 0), (%(name__1)s, %(description__1)s, %(program__1)s, %(leve ... 216 characters truncated ... AS imp_sen(p0, p1, p2, p3, sen_counter) ORDER BY sen_counter RETURNING course.id, course.id AS id__1
# 2024-03-17 15:45:54,951 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (ordered)] {'name__0': 'Python Basics', 'program__0': 'Python', 'description__0': 'Introduction to Python', 'level__0': 1, 'name__1': 'Java Fundamentals', 'program__1': 'Java', 'description__1': 'Introduction to Java', 'level__1': 1, 'name__2': 'Advanced Python', 'program__2': 'Python', 'description__2': 'Advanced Python topics', 'level__2': 2, 'name__3': 'C++ Programming', 'program__3': 'C++', 'description__3': 'Introduction to C++', 'level__3': 1, 'name__4': 'Web Development', 'program__4': 'Web Dev', 'description__4': 'HTML, CSS, JavaScript', 'level__4': 1}
# 2024-03-17 15:45:55,123 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) SELECT p0::VARCHAR, p1::VARCHAR, p2::VARCHAR, p3::TIMESTAMP WITHOUT TIME ZONE, p4::VARCHAR FROM (VALUES (%(name__0)s, %(surname__0)s, %(email__0)s, %(birthdate__0)s, %(address__0)s, 0), ( ... 333 characters truncated ... _sen(p0, p1, p2, p3, p4, sen_counter) ORDER BY sen_counter RETURNING student.id, student.id AS id__1
# 2024-03-17 15:45:55,124 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (ordered)] {'name__0': 'Sarah', 'address__0': '123 Elm St, Anytown', 'email__0': 'sarah.a@example.com', 'birthdate__0': datetime.datetime(1998, 5, 15, 0, 0), 'surname__0': 'Adams', 'name__1': 'James', 'address__1': '456 Oak St, Othertown', 'email__1': 'james.w@example.com', 'birthdate__1': datetime.datetime(1999, 8, 20, 0, 0), 'surname__1': 'Wilson', 'name__2': 'Emma', 'address__2': '789 Maple Ave, Anycity', 'email__2': 'emma.l@example.com', 'birthdate__2': datetime.datetime(2000, 3, 10, 0, 0), 'surname__2': 'Lee', 'name__3': 'Ethan', 'address__3': '101 Pine St, Somewhere', 'email__3': 'ethan.t@example.com', 'birthdate__3': datetime.datetime(1997, 11, 30, 0, 0), 'surname__3': 'Taylor', 'name__4': 'Olivia', 'address__4': '222 Cedar St, Nowhere', 'email__4': 'olivia.w@example.com', 'birthdate__4': datetime.datetime(1996, 2, 25, 0, 0), 'surname__4': 'Wright'}
# 2024-03-17 15:45:55,319 INFO sqlalchemy.engine.Engine INSERT INTO teacher (name, surname, email) SELECT p0::VARCHAR, p1::VARCHAR, p2::VARCHAR FROM (VALUES (%(name__0)s, %(surname__0)s, %(email__0)s, 0), (%(name__1)s, %(surname__1)s, %(email__1)s, 1), (%(name__2)s, %(surname__2)s, %(email__2)s, 2), (%(name__3)s, %(surname__3)s, %(email__3)s, 3), (%(name__4)s, %(surname__4)s, %(email__4)s, 4)) AS imp_sen(p0, p1, p2, sen_counter) ORDER BY sen_counter RETURNING teacher.id, teacher.id AS id__1
# 2024-03-17 15:45:55,319 INFO sqlalchemy.engine.Engine [generated in 0.00008s (insertmanyvalues) 1/1 (ordered)] {'name__0': 'John', 'email__0': 'john.doe@example.com', 'surname__0': 'Doe', 'name__1': 'Alice', 'email__1': 'alice.smith@example.com', 'surname__1': 'Smith', 'name__2': 'Michael', 'email__2': 'michael.j@example.com', 'surname__2': 'Johnson', 'name__3': 'Emily', 'email__3': 'emily.b@example.com', 'surname__3': 'Brown', 'name__4': 'David', 'email__4': 'david.m@example.com', 'surname__4': 'Miller'}
# 2024-03-17 15:45:55,383 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:45:55,433 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:45:55,435 INFO sqlalchemy.engine.Engine INSERT INTO course_instance (start_date, end_date, base_price, course_id, teacher_id, format, course_type) SELECT p0::TIMESTAMP WITHOUT TIME ZONE, p1::TIMESTAMP WITHOUT TIME ZONE, p2::FLOAT, p3::INTEGER, p4::INTEGER, p5::VARCHAR, p6::VARCHAR FROM (VA ... 695 characters truncated ...  p5, p6, sen_counter) ORDER BY sen_counter RETURNING course_instance.id, course_instance.id AS id__1
# 2024-03-17 15:45:55,435 INFO sqlalchemy.engine.Engine [generated in 0.00011s (insertmanyvalues) 1/1 (ordered)] {'base_price__0': 200.0, 'end_date__0': datetime.datetime(2024, 6, 30, 15, 0), 'teacher_id__0': 1, 'start_date__0': datetime.datetime(2024, 4, 1, 10, 0), 'course_type__0': 'Live class', 'course_id__0': 1, 'format__0': 'Online', 'base_price__1': 250.0, 'end_date__1': datetime.datetime(2024, 8, 20, 12, 0), 'teacher_id__1': 2, 'start_date__1': datetime.datetime(2024, 5, 10, 9, 0), 'course_type__1': 'Camp', 'course_id__1': 2, 'format__1': 'In-person', 'base_price__2': 300.0, 'end_date__2': datetime.datetime(2024, 9, 30, 18, 0), 'teacher_id__2': 3, 'start_date__2': datetime.datetime(2024, 6, 15, 13, 0), 'course_type__2': '1on1', 'course_id__2': 3, 'format__2': 'Hybrid', 'base_price__3': 220.0, 'end_date__3': datetime.datetime(2024, 10, 25, 16, 0), 'teacher_id__3': 4, 'start_date__3': datetime.datetime(2024, 7, 20, 11, 0), 'course_type__3': 'Live class', 'course_id__3': 4, 'format__3': 'Online', 'base_price__4': 270.0, 'end_date__4': datetime.datetime(2024, 11, 15, 14, 0), 'teacher_id__4': 5, 'start_date__4': datetime.datetime(2024, 8, 5, 10, 0), 'course_type__4': 'Camp', 'course_id__4': 5, 'format__4': 'In-person'}
# 2024-03-17 15:45:55,556 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:45:55,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:45:55,626 INFO sqlalchemy.engine.Engine INSERT INTO certificate (student_id, course_instance_id, issue_date, url) SELECT p0::INTEGER, p1::INTEGER, p2::TIMESTAMP WITHOUT TIME ZONE, p3::VARCHAR FROM (VALUES (%(student_id__0)s, %(course_instance_id__0)s, %(issue_date__0)s, %(url__0)s, 0), (%( ... 335 characters truncated ... (p0, p1, p2, p3, sen_counter) ORDER BY sen_counter RETURNING certificate.id, certificate.id AS id__1
# 2024-03-17 15:45:55,644 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (ordered)] {'course_instance_id__0': 1, 'issue_date__0': datetime.datetime(2024, 6, 30, 15, 0), 'url__0': 'https://example.com/1', 'student_id__0': 1, 'course_instance_id__1': 2, 'issue_date__1': datetime.datetime(2024, 8, 20, 12, 0), 'url__1': 'https://example.com/2', 'student_id__1': 2, 'course_instance_id__2': 3, 'issue_date__2': datetime.datetime(2024, 9, 30, 18, 0), 'url__2': 'https://example.com/3', 'student_id__2': 3, 'course_instance_id__3': 4, 'issue_date__3': datetime.datetime(2024, 10, 25, 16, 0), 'url__3': 'https://example.com/4', 'student_id__3': 4, 'course_instance_id__4': 5, 'issue_date__4': datetime.datetime(2024, 11, 15, 14, 0), 'url__4': 'https://example.com/5', 'student_id__4': 5}
# 2024-03-17 15:45:55,755 INFO sqlalchemy.engine.Engine INSERT INTO lesson (session_number, course_instance_id, date, recording_url) SELECT p0::INTEGER, p1::INTEGER, p2::TIMESTAMP WITHOUT TIME ZONE, p3::VARCHAR FROM (VALUES (%(session_number__0)s, %(course_instance_id__0)s, %(date__0)s, %(recording_url__0 ... 368 characters truncated ... AS imp_sen(p0, p1, p2, p3, sen_counter) ORDER BY sen_counter RETURNING lesson.id, lesson.id AS id__1
# 2024-03-17 15:45:55,756 INFO sqlalchemy.engine.Engine [generated in 0.00006s (insertmanyvalues) 1/1 (ordered)] {'session_number__0': 1, 'course_instance_id__0': 1, 'date__0': datetime.datetime(2024, 4, 5, 10, 0), 'recording_url__0': 'https://example.com/1', 'session_number__1': 1, 'course_instance_id__1': 2, 'date__1': datetime.datetime(2024, 5, 12, 9, 0), 'recording_url__1': 'https://example.com/2', 'session_number__2': 1, 'course_instance_id__2': 3, 'date__2': datetime.datetime(2024, 6, 17, 13, 0), 'recording_url__2': 'https://example.com/3', 'session_number__3': 1, 'course_instance_id__3': 4, 'date__3': datetime.datetime(2024, 7, 22, 11, 0), 'recording_url__3': 'https://example.com/4', 'session_number__4': 1, 'course_instance_id__4': 5, 'date__4': datetime.datetime(2024, 8, 7, 10, 0), 'recording_url__4': 'https://example.com/5'}
# 2024-03-17 15:45:55,813 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) SELECT p0::TIMESTAMP WITHOUT TIME ZONE, p1::FLOAT, p2::INTEGER, p3::INTEGER FROM (VALUES (%(purchase_date__0)s, %(amount__0)s, %(student_id__0)s, %(course_instance_id__0)s,  ... 360 characters truncated ... mp_sen(p0, p1, p2, p3, sen_counter) ORDER BY sen_counter RETURNING purchase.id, purchase.id AS id__1
# 2024-03-17 15:45:55,814 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (ordered)] {'course_instance_id__0': 1, 'amount__0': 200.0, 'purchase_date__0': datetime.datetime(2024, 4, 2, 8, 30), 'student_id__0': 1, 'course_instance_id__1': 2, 'amount__1': 250.0, 'purchase_date__1': datetime.datetime(2024, 5, 15, 11, 45), 'student_id__1': 2, 'course_instance_id__2': 3, 'amount__2': 300.0, 'purchase_date__2': datetime.datetime(2024, 6, 20, 14, 20), 'student_id__2': 3, 'course_instance_id__3': 4, 'amount__3': 220.0, 'purchase_date__3': datetime.datetime(2024, 7, 25, 9, 0), 'student_id__3': 4, 'course_instance_id__4': 5, 'amount__4': 270.0, 'purchase_date__4': datetime.datetime(2024, 8, 6, 12, 10), 'student_id__4': 5}
# 2024-03-17 15:45:55,873 INFO sqlalchemy.engine.Engine INSERT INTO student_course (student_id, course_instance_id, status) SELECT p0::INTEGER, p1::INTEGER, p2::VARCHAR FROM (VALUES (%(student_id__0)s, %(course_instance_id__0)s, %(status__0)s, 0), (%(student_id__1)s, %(course_instance_id__1)s, %(status__1 ... 218 characters truncated ... 0, p1, p2, sen_counter) ORDER BY sen_counter RETURNING student_course.id, student_course.id AS id__1
# 2024-03-17 15:45:55,874 INFO sqlalchemy.engine.Engine [generated in 0.00006s (insertmanyvalues) 1/1 (ordered)] {'course_instance_id__0': 1, 'status__0': 'Enrolled', 'student_id__0': 1, 'course_instance_id__1': 2, 'status__1': 'Enrolled', 'student_id__1': 2, 'course_instance_id__2': 3, 'status__2': 'Enrolled', 'student_id__2': 3, 'course_instance_id__3': 4, 'status__3': 'Enrolled', 'student_id__3': 4, 'course_instance_id__4': 5, 'status__4': 'Enrolled', 'student_id__4': 5}
# 2024-03-17 15:45:55,938 INFO sqlalchemy.engine.Engine COMMIT

# %%
def purchase_course(student_id, course_instance_id, amount, purchase_date):
    purchase = Purchase(student_id=student_id, course_instance_id=course_instance_id, amount=amount, purchase_date=purchase_date)
    session.add(purchase)
    session.commit()

def create_new_student(name, surname, email, birthdate, address):
    student = Student(name=name, surname=surname, email=email, birthdate=birthdate, address=address)
    session.add(student)
    session.commit()

def create_new_teacher(name, surname, email):
    teacher = Teacher(name=name, surname=surname, email=email)
    session.add(teacher)
    session.commit()

def create_new_course(name, description, program, level):
    course = Course(name=name, description=description, program=program, level=level)
    session.add(course)
    session.commit()

def create_new_course_instance(start_date, end_date, base_price, course_id, teacher_id, format, course_type):
    course_instance = CourseInstance(start_date=start_date, end_date=end_date, base_price=base_price, course_id=course_id, teacher_id=teacher_id, format=format, course_type=course_type)
    session.add(course_instance)
    session.commit()

def create_new_student_course(student_id, course_instance_id, status):
    student_course = StudentCourse(student_id=student_id, course_instance_id=course_instance_id, status=status)
    session.add(student_course)
    session.commit()

def create_new_lesson(session_number, course_instance_id, date, recording_url):
    lesson = Lesson(session_number=session_number, course_instance_id=course_instance_id, date=date, recording_url=recording_url)
    session.add(lesson)
    session.commit()

# %%
def test_10000_student_creation_performance():
    start_time = datetime.now()
    for i in range(10000):
        create_new_student(f"Student_{i+1}", "Surname", f"Surname_{i+1}", datetime(2000, 1, 1), f"Address_{i+1}")
    end_time = datetime.now()
    print(f"1000 students created in {end_time - start_time}")

def test_10000_purchase_creation_performance():
    start_time = datetime.now()
    for i in range(10000):
        purchase_course(1, 1, 200.00, datetime(2024, 4, 2, 8, 30))
    end_time = datetime.now()
    print(f"1000 purchases created in {end_time - start_time}")

# %%
# 1300 records in 5 mins
test_10000_purchase_creation_performance()
# Out:
# 2024-03-17 15:50:59,061 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:50:59,066 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:50:59,068 INFO sqlalchemy.engine.Engine [generated in 0.00186s] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:50:59,215 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:50:59,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:50:59,335 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:50:59,336 INFO sqlalchemy.engine.Engine [cached since 0.2701s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:50:59,454 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:50:59,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:50:59,509 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:50:59,509 INFO sqlalchemy.engine.Engine [cached since 0.4433s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:50:59,634 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:50:59,778 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:50:59,779 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:50:59,779 INFO sqlalchemy.engine.Engine [cached since 0.7136s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:50:59,876 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:50:59,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:50:59,935 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:50:59,935 INFO sqlalchemy.engine.Engine [cached since 0.8698s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:00,089 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:00,138 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:00,139 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:00,139 INFO sqlalchemy.engine.Engine [cached since 1.074s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:00,313 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:00,359 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:00,360 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:00,360 INFO sqlalchemy.engine.Engine [cached since 1.295s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:00,572 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:00,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:00,624 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:00,624 INFO sqlalchemy.engine.Engine [cached since 1.559s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:01,007 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:01,074 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:01,075 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:01,076 INFO sqlalchemy.engine.Engine [cached since 2.01s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:01,208 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:01,268 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:01,269 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:01,269 INFO sqlalchemy.engine.Engine [cached since 2.204s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:01,548 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:01,704 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:01,705 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:01,706 INFO sqlalchemy.engine.Engine [cached since 2.64s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:01,811 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:01,858 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:01,859 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:01,860 INFO sqlalchemy.engine.Engine [cached since 2.794s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:01,961 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:02,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:02,065 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:02,065 INFO sqlalchemy.engine.Engine [cached since 2.999s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:02,159 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:02,211 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:02,213 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:02,214 INFO sqlalchemy.engine.Engine [cached since 3.149s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:02,312 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:02,356 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:02,357 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:02,358 INFO sqlalchemy.engine.Engine [cached since 3.292s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:02,456 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:02,504 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:02,505 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:02,505 INFO sqlalchemy.engine.Engine [cached since 3.44s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:02,596 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:02,728 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:02,730 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:02,730 INFO sqlalchemy.engine.Engine [cached since 3.665s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:02,821 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:02,966 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:02,968 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:02,969 INFO sqlalchemy.engine.Engine [cached since 3.903s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:03,091 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:03,136 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:03,137 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:03,137 INFO sqlalchemy.engine.Engine [cached since 4.071s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:03,309 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:03,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:03,377 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:03,377 INFO sqlalchemy.engine.Engine [cached since 4.311s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:03,484 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:03,534 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:03,535 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:03,536 INFO sqlalchemy.engine.Engine [cached since 4.47s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:03,627 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:03,678 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:03,679 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:03,680 INFO sqlalchemy.engine.Engine [cached since 4.614s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:03,775 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:03,823 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:03,824 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:03,824 INFO sqlalchemy.engine.Engine [cached since 4.758s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:04,087 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:04,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:04,144 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:04,145 INFO sqlalchemy.engine.Engine [cached since 5.079s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:04,260 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:04,323 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:04,324 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:04,325 INFO sqlalchemy.engine.Engine [cached since 5.259s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:04,448 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:04,495 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:04,496 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:04,496 INFO sqlalchemy.engine.Engine [cached since 5.43s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:04,610 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:04,675 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:04,675 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:04,676 INFO sqlalchemy.engine.Engine [cached since 5.61s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:04,767 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:04,818 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:04,819 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:04,820 INFO sqlalchemy.engine.Engine [cached since 5.754s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:04,924 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:04,990 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:04,991 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:04,991 INFO sqlalchemy.engine.Engine [cached since 5.925s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:05,201 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:05,258 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:05,259 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:05,259 INFO sqlalchemy.engine.Engine [cached since 6.194s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:05,355 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:05,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:05,429 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:05,430 INFO sqlalchemy.engine.Engine [cached since 6.364s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:05,536 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:05,583 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:05,585 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:05,585 INFO sqlalchemy.engine.Engine [cached since 6.519s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:05,689 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:05,738 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:05,739 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:05,739 INFO sqlalchemy.engine.Engine [cached since 6.674s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:05,841 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:05,897 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:05,898 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:05,899 INFO sqlalchemy.engine.Engine [cached since 6.833s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:05,998 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:06,042 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:06,043 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:06,043 INFO sqlalchemy.engine.Engine [cached since 6.977s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:06,162 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:06,220 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:06,221 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:06,221 INFO sqlalchemy.engine.Engine [cached since 7.156s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:06,321 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:06,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:06,377 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:06,377 INFO sqlalchemy.engine.Engine [cached since 7.312s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:06,473 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:06,530 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:06,531 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:06,532 INFO sqlalchemy.engine.Engine [cached since 7.466s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:06,835 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:06,886 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:06,887 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:06,888 INFO sqlalchemy.engine.Engine [cached since 7.822s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,030 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:07,080 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:07,081 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:07,081 INFO sqlalchemy.engine.Engine [cached since 8.016s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,191 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:07,242 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:07,243 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:07,243 INFO sqlalchemy.engine.Engine [cached since 8.178s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,356 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:07,406 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:07,407 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:07,407 INFO sqlalchemy.engine.Engine [cached since 8.341s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,511 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:07,570 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:07,571 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:07,572 INFO sqlalchemy.engine.Engine [cached since 8.506s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,673 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:07,730 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:07,730 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:07,731 INFO sqlalchemy.engine.Engine [cached since 8.665s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,829 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:07,886 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:07,886 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:07,886 INFO sqlalchemy.engine.Engine [cached since 8.821s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:07,981 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:08,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:08,216 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:08,216 INFO sqlalchemy.engine.Engine [cached since 9.15s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:08,361 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:08,488 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:08,490 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:08,491 INFO sqlalchemy.engine.Engine [cached since 9.425s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:08,721 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:08,773 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:08,774 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:08,775 INFO sqlalchemy.engine.Engine [cached since 9.709s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:08,875 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:08,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:08,936 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:08,937 INFO sqlalchemy.engine.Engine [cached since 9.871s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:09,041 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:09,107 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:09,107 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:09,108 INFO sqlalchemy.engine.Engine [cached since 10.04s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:09,217 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:09,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:09,264 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:09,265 INFO sqlalchemy.engine.Engine [cached since 10.2s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:09,366 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:09,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:09,421 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:09,421 INFO sqlalchemy.engine.Engine [cached since 10.36s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:09,534 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:09,591 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:09,592 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:09,593 INFO sqlalchemy.engine.Engine [cached since 10.53s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:09,696 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:09,752 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:09,753 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:09,754 INFO sqlalchemy.engine.Engine [cached since 10.69s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:09,841 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:09,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:09,896 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:09,897 INFO sqlalchemy.engine.Engine [cached since 10.83s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:10,080 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:10,195 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:10,196 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:10,197 INFO sqlalchemy.engine.Engine [cached since 11.13s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:10,315 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:10,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:10,377 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:10,377 INFO sqlalchemy.engine.Engine [cached since 11.31s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:10,641 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:10,697 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:10,698 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:10,699 INFO sqlalchemy.engine.Engine [cached since 11.63s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:10,796 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:10,841 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:10,842 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:10,842 INFO sqlalchemy.engine.Engine [cached since 11.78s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:10,952 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:11,045 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:11,046 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:11,047 INFO sqlalchemy.engine.Engine [cached since 11.98s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:11,157 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:11,216 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:11,217 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:11,217 INFO sqlalchemy.engine.Engine [cached since 12.15s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:11,306 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:11,395 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:11,396 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:11,396 INFO sqlalchemy.engine.Engine [cached since 12.33s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:11,516 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:11,593 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:11,594 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:11,594 INFO sqlalchemy.engine.Engine [cached since 12.53s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:11,706 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:11,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:11,763 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:11,767 INFO sqlalchemy.engine.Engine [cached since 12.7s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:11,871 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:11,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:11,936 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:11,936 INFO sqlalchemy.engine.Engine [cached since 12.87s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:12,050 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:12,268 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:12,269 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:12,269 INFO sqlalchemy.engine.Engine [cached since 13.2s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:12,367 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:12,416 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:12,416 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:12,417 INFO sqlalchemy.engine.Engine [cached since 13.35s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:12,552 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:12,606 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:12,607 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:12,607 INFO sqlalchemy.engine.Engine [cached since 13.54s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:12,715 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:12,774 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:12,775 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:12,775 INFO sqlalchemy.engine.Engine [cached since 13.71s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:12,871 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:12,928 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:12,929 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:12,929 INFO sqlalchemy.engine.Engine [cached since 13.86s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:13,031 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:13,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:13,085 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:13,085 INFO sqlalchemy.engine.Engine [cached since 14.02s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:13,201 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:13,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:13,255 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:13,256 INFO sqlalchemy.engine.Engine [cached since 14.19s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:13,390 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:13,454 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:13,455 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:13,455 INFO sqlalchemy.engine.Engine [cached since 14.39s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:13,558 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:13,619 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:13,620 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:13,620 INFO sqlalchemy.engine.Engine [cached since 14.55s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:13,735 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:13,791 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:13,792 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:13,792 INFO sqlalchemy.engine.Engine [cached since 14.73s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:13,904 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:13,975 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:13,976 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:13,976 INFO sqlalchemy.engine.Engine [cached since 14.91s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:14,088 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:14,155 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:14,156 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:14,157 INFO sqlalchemy.engine.Engine [cached since 15.09s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:14,538 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:14,713 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:14,714 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:14,714 INFO sqlalchemy.engine.Engine [cached since 15.65s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:14,995 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:15,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:15,056 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:15,057 INFO sqlalchemy.engine.Engine [cached since 15.99s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:15,236 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:15,295 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:15,296 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:15,297 INFO sqlalchemy.engine.Engine [cached since 16.23s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:15,409 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:15,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:15,470 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:15,470 INFO sqlalchemy.engine.Engine [cached since 16.4s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:15,595 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:15,651 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:15,652 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:15,653 INFO sqlalchemy.engine.Engine [cached since 16.59s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:15,741 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:15,800 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:15,802 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:15,802 INFO sqlalchemy.engine.Engine [cached since 16.74s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:15,895 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:15,993 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:15,994 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:15,994 INFO sqlalchemy.engine.Engine [cached since 16.93s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:16,135 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:16,183 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:16,184 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:51:16,185 INFO sqlalchemy.engine.Engine [cached since 17.12s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:51:16,551 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:51:16,600 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:51:16,602 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# ...
# 2024-03-17 15:56:08,159 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:08,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:08,215 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:56:08,216 INFO sqlalchemy.engine.Engine [cached since 309.1s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:56:08,353 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:08,409 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:08,410 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:56:08,410 INFO sqlalchemy.engine.Engine [cached since 309.3s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:56:08,554 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:08,604 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:08,604 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:56:08,605 INFO sqlalchemy.engine.Engine [cached since 309.5s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:56:08,702 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:08,773 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:08,773 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:56:08,773 INFO sqlalchemy.engine.Engine [cached since 309.7s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:56:08,875 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:08,929 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:08,930 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:56:08,930 INFO sqlalchemy.engine.Engine [cached since 309.9s ago] {'purchase_date': datetime.datetime(2024, 4, 2, 8, 30), 'amount': 200.0, 'student_id': 1, 'course_instance_id': 1}
# 2024-03-17 15:56:09,069 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:09,129 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:09,130 INFO sqlalchemy.engine.Engine INSERT INTO purchase (purchase_date, amount, student_id, course_instance_id) VALUES (%(purchase_date)s, %(amount)s, %(student_id)s, %(course_instance_id)s) RETURNING purchase.id
# 2024-03-17 15:56:09,134 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 test_10000_purchase_creation_performance()
#
# Cell In[15], line 11, in test_10000_purchase_creation_performance()
#       9 start_time = datetime.now()
#      10 for i in range(10000):
# ---> 11     purchase_course(1, 1, 200.00, datetime(2024, 4, 2, 8, 30))
#      12 end_time = datetime.now()
#      13 print(f"1000 purchases created in {end_time - start_time}")
#
# Cell In[14], line 4, in purchase_course(student_id, course_instance_id, amount, purchase_date)
#       2 purchase = Purchase(student_id=student_id, course_instance_id=course_instance_id, amount=amount, purchase_date=purchase_date)
#       3 session.add(purchase)
# ----> 4 session.commit()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1972, in Session.commit(self)
#    1969 if trans is None:
#    1970     trans = self._autobegin_t()
# -> 1972 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1257, in SessionTransaction.commit(self, _to_root)
#    1255 if self._state is not SessionTransactionState.PREPARED:
#    1256     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1257         self._prepare_impl()
#    1259 if self._parent is None or self.nested:
#    1260     for conn, trans, should_commit, autoclose in set(
#    1261         self._connections.values()
#    1262     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1232, in SessionTransaction._prepare_impl(self)
#    1230     if self.session._is_clean():
#    1231         break
# -> 1232     self.session.flush()
#    1233 else:
#    1234     raise exc.FlushError(
#    1235         "Over 100 subsequent flushes have occurred within "
#    1236         "session.commit() - is an after_flush() hook "
#    1237         "creating new objects?"
#    1238     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4296, in Session.flush(self, objects)
#    4294 try:
#    4295     self._flushing = True
# -> 4296     self._flush(objects)
#    4297 finally:
#    4298     self._flushing = False
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4431, in Session._flush(self, objects)
#    4428     transaction.commit()
#    4430 except:
# -> 4431     with util.safe_reraise():
#    4432         transaction.rollback(_capture_exception=True)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4392, in Session._flush(self, objects)
#    4390 self._warn_on_events = True
#    4391 try:
# -> 4392     flush_context.execute()
#    4393 finally:
#    4394     self._warn_on_events = False
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1421, in Connection.execute(self, statement, parameters, execution_options)
#    1419     raise exc.ObjectNotExecutableError(statement) from err
#    1420 else:
# -> 1421     return meth(
#    1422         self,
#    1423         distilled_parameters,
#    1424         execution_options or NO_OPTIONS,
#    1425     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:514, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     512     if TYPE_CHECKING:
#     513         assert isinstance(self, Executable)
# --> 514     return connection._execute_clauseelement(
#     515         self, distilled_params, execution_options
#     516     )
#     517 else:
#     518     raise exc.ObjectNotExecutableError(self)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1643, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1631 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1632     "compiled_cache", self.engine._compiled_cache
#    1633 )
#    1635 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1636     dialect=dialect,
#    1637     compiled_cache=compiled_cache,
#    (...)
#    1641     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1642 )
# -> 1643 ret = self._execute_context(
#    1644     dialect,
#    1645     dialect.execution_ctx_cls._init_compiled,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     execution_options,
#    1649     compiled_sql,
#    1650     distilled_parameters,
#    1651     elem,
#    1652     extracted_params,
#    1653     cache_hit=cache_hit,
#    1654 )
#    1655 if has_events:
#    1656     self.dispatch.after_execute(
#    1657         self,
#    1658         elem,
#    (...)
#    1662         ret,
#    1663     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1849, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1847     return self._exec_insertmany_context(dialect, context)
#    1848 else:
# -> 1849     return self._exec_single_context(
#    1850         dialect, context, statement, parameters
#    1851     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1907, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1904 stats = context._get_cache_stats()
#    1906 if not self.engine.hide_parameters:
# -> 1907     self._log_info(
#    1908         "[%s] %r",
#    1909         stats,
#    1910         sql_util._repr_params(
#    1911             effective_parameters,
#    1912             batches=10,
#    1913             ismulti=context.executemany,
#    1914         ),
#    1915     )
#    1916 else:
#    1917     self._log_info(
#    1918         "[%s] [SQL parameters hidden due to hide_parameters=True]",
#    1919         stats,
#    1920     )
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:193, in Connection._log_info(self, message, *arg, **kw)
#     190 if log.STACKLEVEL:
#     191     kw["stacklevel"] = 1 + log.STACKLEVEL_OFFSET
# --> 193 self.engine.logger.info(message, *arg, **kw)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/log.py:159, in InstanceLogger.info(self, msg, *args, **kwargs)
#     156 def info(self, msg: str, *args: Any, **kwargs: Any) -> None:
#     157     """Delegate an info call to the underlying logger."""
# --> 159     self.log(logging.INFO, msg, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/log.py:210, in InstanceLogger.log(self, level, msg, *args, **kwargs)
#     205 if STACKLEVEL:
#     206     kwargs["stacklevel"] = (
#     207         kwargs.get("stacklevel", 1) + STACKLEVEL_OFFSET
#     208     )
# --> 210 self.logger._log(level, msg, args, **kwargs)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:1100, in StreamHandler.emit(self, record)
#    1089 """
#    1090 Emit a record.
#    1091
#    (...)
#    1097 output to the stream.
#    1098 """
#    1099 try:
# -> 1100     msg = self.format(record)
#    1101     stream = self.stream
#    1102     # issue 35046: merged two stream.writes into one.
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:943, in Handler.format(self, record)
#     941 else:
#     942     fmt = _defaultFormatter
# --> 943 return fmt.format(record)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:680, in Formatter.format(self, record)
#     678 record.message = record.getMessage()
#     679 if self.usesTime():
# --> 680     record.asctime = self.formatTime(record, self.datefmt)
#     681 s = self.formatMessage(record)
#     682 if record.exc_info:
#     683     # Cache the traceback text to avoid converting it multiple times
#     684     # (it's constant anyway)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/logging/__init__.py:619, in Formatter.formatTime(self, record, datefmt)
#     617     s = time.strftime(datefmt, ct)
#     618 else:
# --> 619     s = time.strftime(self.default_time_format, ct)
#     620     if self.default_msec_format:
#     621         s = self.default_msec_format % (s, record.msecs)
#
# KeyboardInterrupt:

# %%
session.rollback()
# 3500 in 13 mins
test_10000_student_creation_performance()
# Out:
# 2024-03-17 15:56:58,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:58,187 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:58,187 INFO sqlalchemy.engine.Engine [generated in 0.00088s] {'name': 'Student_1', 'surname': 'Surname', 'email': 'Surname_1', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_1'}
# /var/folders/37/bjw8h3jd7037t7fyq2_pmymm0000gn/T/ipykernel_33122/3990733814.py:1: SAWarning: Session's state has been changed on a non-active transaction - this state will be discarded.
#   session.rollback()
# 2024-03-17 15:56:58,562 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:58,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:58,623 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:58,623 INFO sqlalchemy.engine.Engine [cached since 0.437s ago] {'name': 'Student_2', 'surname': 'Surname', 'email': 'Surname_2', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_2'}
# 2024-03-17 15:56:58,742 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:58,789 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:58,790 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:58,790 INFO sqlalchemy.engine.Engine [cached since 0.6037s ago] {'name': 'Student_3', 'surname': 'Surname', 'email': 'Surname_3', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3'}
# 2024-03-17 15:56:58,892 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:58,949 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:58,950 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:58,950 INFO sqlalchemy.engine.Engine [cached since 0.764s ago] {'name': 'Student_4', 'surname': 'Surname', 'email': 'Surname_4', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_4'}
# 2024-03-17 15:56:59,057 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:59,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:59,117 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:59,118 INFO sqlalchemy.engine.Engine [cached since 0.9316s ago] {'name': 'Student_5', 'surname': 'Surname', 'email': 'Surname_5', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_5'}
# 2024-03-17 15:56:59,216 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:59,344 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:59,345 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:59,346 INFO sqlalchemy.engine.Engine [cached since 1.16s ago] {'name': 'Student_6', 'surname': 'Surname', 'email': 'Surname_6', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_6'}
# 2024-03-17 15:56:59,472 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:56:59,526 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:56:59,527 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:56:59,527 INFO sqlalchemy.engine.Engine [cached since 1.341s ago] {'name': 'Student_7', 'surname': 'Surname', 'email': 'Surname_7', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_7'}
# 2024-03-17 15:56:59,966 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:00,109 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:00,111 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:00,111 INFO sqlalchemy.engine.Engine [cached since 1.925s ago] {'name': 'Student_8', 'surname': 'Surname', 'email': 'Surname_8', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_8'}
# 2024-03-17 15:57:00,235 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:00,302 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:00,303 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:00,303 INFO sqlalchemy.engine.Engine [cached since 2.117s ago] {'name': 'Student_9', 'surname': 'Surname', 'email': 'Surname_9', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_9'}
# 2024-03-17 15:57:00,421 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:00,482 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:00,484 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:00,484 INFO sqlalchemy.engine.Engine [cached since 2.298s ago] {'name': 'Student_10', 'surname': 'Surname', 'email': 'Surname_10', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_10'}
# 2024-03-17 15:57:00,806 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:00,869 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:00,870 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:00,871 INFO sqlalchemy.engine.Engine [cached since 2.685s ago] {'name': 'Student_11', 'surname': 'Surname', 'email': 'Surname_11', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_11'}
# 2024-03-17 15:57:01,026 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:01,204 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:01,205 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:01,205 INFO sqlalchemy.engine.Engine [cached since 3.019s ago] {'name': 'Student_12', 'surname': 'Surname', 'email': 'Surname_12', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_12'}
# 2024-03-17 15:57:01,327 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:01,382 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:01,383 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:01,383 INFO sqlalchemy.engine.Engine [cached since 3.196s ago] {'name': 'Student_13', 'surname': 'Surname', 'email': 'Surname_13', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_13'}
# 2024-03-17 15:57:01,502 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:01,644 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:01,646 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:01,647 INFO sqlalchemy.engine.Engine [cached since 3.46s ago] {'name': 'Student_14', 'surname': 'Surname', 'email': 'Surname_14', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_14'}
# 2024-03-17 15:57:01,752 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:01,803 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:01,804 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:01,805 INFO sqlalchemy.engine.Engine [cached since 3.618s ago] {'name': 'Student_15', 'surname': 'Surname', 'email': 'Surname_15', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_15'}
# 2024-03-17 15:57:01,902 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:01,969 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:01,971 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:01,972 INFO sqlalchemy.engine.Engine [cached since 3.785s ago] {'name': 'Student_16', 'surname': 'Surname', 'email': 'Surname_16', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_16'}
# 2024-03-17 15:57:02,066 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:02,114 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:02,115 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:02,115 INFO sqlalchemy.engine.Engine [cached since 3.929s ago] {'name': 'Student_17', 'surname': 'Surname', 'email': 'Surname_17', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_17'}
# 2024-03-17 15:57:02,230 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:02,289 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:02,290 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:02,290 INFO sqlalchemy.engine.Engine [cached since 4.104s ago] {'name': 'Student_18', 'surname': 'Surname', 'email': 'Surname_18', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_18'}
# 2024-03-17 15:57:02,633 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:02,763 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:02,764 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:02,765 INFO sqlalchemy.engine.Engine [cached since 4.579s ago] {'name': 'Student_19', 'surname': 'Surname', 'email': 'Surname_19', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_19'}
# 2024-03-17 15:57:02,857 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:02,914 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:02,915 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:02,916 INFO sqlalchemy.engine.Engine [cached since 4.729s ago] {'name': 'Student_20', 'surname': 'Surname', 'email': 'Surname_20', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_20'}
# 2024-03-17 15:57:03,017 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:03,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:03,065 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:03,066 INFO sqlalchemy.engine.Engine [cached since 4.879s ago] {'name': 'Student_21', 'surname': 'Surname', 'email': 'Surname_21', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_21'}
# 2024-03-17 15:57:03,177 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:03,225 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:03,226 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:03,226 INFO sqlalchemy.engine.Engine [cached since 5.04s ago] {'name': 'Student_22', 'surname': 'Surname', 'email': 'Surname_22', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_22'}
# 2024-03-17 15:57:03,356 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:03,416 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:03,417 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:03,418 INFO sqlalchemy.engine.Engine [cached since 5.231s ago] {'name': 'Student_23', 'surname': 'Surname', 'email': 'Surname_23', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_23'}
# 2024-03-17 15:57:03,532 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:03,585 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:03,586 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:03,586 INFO sqlalchemy.engine.Engine [cached since 5.4s ago] {'name': 'Student_24', 'surname': 'Surname', 'email': 'Surname_24', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_24'}
# 2024-03-17 15:57:03,741 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:03,800 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:03,801 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:03,802 INFO sqlalchemy.engine.Engine [cached since 5.615s ago] {'name': 'Student_25', 'surname': 'Surname', 'email': 'Surname_25', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_25'}
# 2024-03-17 15:57:03,902 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:03,963 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:03,963 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:03,964 INFO sqlalchemy.engine.Engine [cached since 5.777s ago] {'name': 'Student_26', 'surname': 'Surname', 'email': 'Surname_26', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_26'}
# 2024-03-17 15:57:04,083 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:04,131 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:04,132 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:04,132 INFO sqlalchemy.engine.Engine [cached since 5.946s ago] {'name': 'Student_27', 'surname': 'Surname', 'email': 'Surname_27', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_27'}
# 2024-03-17 15:57:04,262 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:04,323 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:04,324 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:04,324 INFO sqlalchemy.engine.Engine [cached since 6.138s ago] {'name': 'Student_28', 'surname': 'Surname', 'email': 'Surname_28', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_28'}
# 2024-03-17 15:57:04,436 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:04,485 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:04,486 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:04,487 INFO sqlalchemy.engine.Engine [cached since 6.3s ago] {'name': 'Student_29', 'surname': 'Surname', 'email': 'Surname_29', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_29'}
# 2024-03-17 15:57:04,584 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:04,628 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:04,629 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:04,630 INFO sqlalchemy.engine.Engine [cached since 6.443s ago] {'name': 'Student_30', 'surname': 'Surname', 'email': 'Surname_30', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_30'}
# 2024-03-17 15:57:04,750 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:04,864 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:04,865 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:04,866 INFO sqlalchemy.engine.Engine [cached since 6.679s ago] {'name': 'Student_31', 'surname': 'Surname', 'email': 'Surname_31', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_31'}
# 2024-03-17 15:57:04,972 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:05,043 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:05,044 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:05,044 INFO sqlalchemy.engine.Engine [cached since 6.858s ago] {'name': 'Student_32', 'surname': 'Surname', 'email': 'Surname_32', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_32'}
# 2024-03-17 15:57:05,157 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:05,207 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:05,208 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:05,209 INFO sqlalchemy.engine.Engine [cached since 7.022s ago] {'name': 'Student_33', 'surname': 'Surname', 'email': 'Surname_33', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_33'}
# 2024-03-17 15:57:05,309 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:05,359 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:05,360 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:05,361 INFO sqlalchemy.engine.Engine [cached since 7.174s ago] {'name': 'Student_34', 'surname': 'Surname', 'email': 'Surname_34', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_34'}
# 2024-03-17 15:57:05,487 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:05,549 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:05,551 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:05,551 INFO sqlalchemy.engine.Engine [cached since 7.365s ago] {'name': 'Student_35', 'surname': 'Surname', 'email': 'Surname_35', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_35'}
# 2024-03-17 15:57:05,660 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:05,716 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:05,716 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:05,717 INFO sqlalchemy.engine.Engine [cached since 7.53s ago] {'name': 'Student_36', 'surname': 'Surname', 'email': 'Surname_36', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_36'}
# 2024-03-17 15:57:05,822 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:05,869 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:05,870 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:05,871 INFO sqlalchemy.engine.Engine [cached since 7.684s ago] {'name': 'Student_37', 'surname': 'Surname', 'email': 'Surname_37', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_37'}
# 2024-03-17 15:57:06,004 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:06,063 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:06,063 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:06,064 INFO sqlalchemy.engine.Engine [cached since 7.877s ago] {'name': 'Student_38', 'surname': 'Surname', 'email': 'Surname_38', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_38'}
# 2024-03-17 15:57:06,166 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:06,211 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:06,212 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:06,212 INFO sqlalchemy.engine.Engine [cached since 8.026s ago] {'name': 'Student_39', 'surname': 'Surname', 'email': 'Surname_39', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_39'}
# 2024-03-17 15:57:06,312 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:06,435 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:06,436 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:06,436 INFO sqlalchemy.engine.Engine [cached since 8.25s ago] {'name': 'Student_40', 'surname': 'Surname', 'email': 'Surname_40', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_40'}
# 2024-03-17 15:57:06,533 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:06,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:06,591 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:06,592 INFO sqlalchemy.engine.Engine [cached since 8.405s ago] {'name': 'Student_41', 'surname': 'Surname', 'email': 'Surname_41', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_41'}
# 2024-03-17 15:57:06,919 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:06,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:06,980 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:06,981 INFO sqlalchemy.engine.Engine [cached since 8.794s ago] {'name': 'Student_42', 'surname': 'Surname', 'email': 'Surname_42', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_42'}
# 2024-03-17 15:57:07,082 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:07,144 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:07,145 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:07,146 INFO sqlalchemy.engine.Engine [cached since 8.959s ago] {'name': 'Student_43', 'surname': 'Surname', 'email': 'Surname_43', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_43'}
# 2024-03-17 15:57:07,263 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:07,325 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:07,326 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:07,327 INFO sqlalchemy.engine.Engine [cached since 9.14s ago] {'name': 'Student_44', 'surname': 'Surname', 'email': 'Surname_44', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_44'}
# 2024-03-17 15:57:07,434 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:07,542 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:07,543 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:07,544 INFO sqlalchemy.engine.Engine [cached since 9.357s ago] {'name': 'Student_45', 'surname': 'Surname', 'email': 'Surname_45', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_45'}
# 2024-03-17 15:57:07,732 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:07,803 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:07,804 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:07,805 INFO sqlalchemy.engine.Engine [cached since 9.618s ago] {'name': 'Student_46', 'surname': 'Surname', 'email': 'Surname_46', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_46'}
# 2024-03-17 15:57:07,921 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:07,982 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:07,984 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:07,985 INFO sqlalchemy.engine.Engine [cached since 9.798s ago] {'name': 'Student_47', 'surname': 'Surname', 'email': 'Surname_47', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_47'}
# 2024-03-17 15:57:08,087 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:08,132 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:08,133 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:08,133 INFO sqlalchemy.engine.Engine [cached since 9.947s ago] {'name': 'Student_48', 'surname': 'Surname', 'email': 'Surname_48', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_48'}
# 2024-03-17 15:57:08,231 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:08,304 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:08,305 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:08,305 INFO sqlalchemy.engine.Engine [cached since 10.12s ago] {'name': 'Student_49', 'surname': 'Surname', 'email': 'Surname_49', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_49'}
# 2024-03-17 15:57:08,409 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:08,463 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:08,464 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:08,464 INFO sqlalchemy.engine.Engine [cached since 10.28s ago] {'name': 'Student_50', 'surname': 'Surname', 'email': 'Surname_50', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_50'}
# 2024-03-17 15:57:08,579 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:08,637 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:08,638 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:08,638 INFO sqlalchemy.engine.Engine [cached since 10.45s ago] {'name': 'Student_51', 'surname': 'Surname', 'email': 'Surname_51', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_51'}
# 2024-03-17 15:57:08,763 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:08,823 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:08,826 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:08,827 INFO sqlalchemy.engine.Engine [cached since 10.64s ago] {'name': 'Student_52', 'surname': 'Surname', 'email': 'Surname_52', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_52'}
# 2024-03-17 15:57:08,947 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:09,004 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:09,005 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:09,005 INFO sqlalchemy.engine.Engine [cached since 10.82s ago] {'name': 'Student_53', 'surname': 'Surname', 'email': 'Surname_53', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_53'}
# 2024-03-17 15:57:09,108 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:09,302 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:09,303 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:09,303 INFO sqlalchemy.engine.Engine [cached since 11.12s ago] {'name': 'Student_54', 'surname': 'Surname', 'email': 'Surname_54', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_54'}
# 2024-03-17 15:57:09,428 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:09,611 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:09,622 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:09,622 INFO sqlalchemy.engine.Engine [cached since 11.44s ago] {'name': 'Student_55', 'surname': 'Surname', 'email': 'Surname_55', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_55'}
# 2024-03-17 15:57:09,920 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:09,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:09,971 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:09,972 INFO sqlalchemy.engine.Engine [cached since 11.79s ago] {'name': 'Student_56', 'surname': 'Surname', 'email': 'Surname_56', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_56'}
# 2024-03-17 15:57:10,084 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:10,137 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:10,139 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:10,140 INFO sqlalchemy.engine.Engine [cached since 11.95s ago] {'name': 'Student_57', 'surname': 'Surname', 'email': 'Surname_57', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_57'}
# 2024-03-17 15:57:10,406 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:10,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:10,471 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:10,472 INFO sqlalchemy.engine.Engine [cached since 12.28s ago] {'name': 'Student_58', 'surname': 'Surname', 'email': 'Surname_58', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_58'}
# 2024-03-17 15:57:10,572 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:10,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:10,626 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:10,628 INFO sqlalchemy.engine.Engine [cached since 12.44s ago] {'name': 'Student_59', 'surname': 'Surname', 'email': 'Surname_59', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_59'}
# 2024-03-17 15:57:10,746 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:10,803 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:10,803 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:10,804 INFO sqlalchemy.engine.Engine [cached since 12.62s ago] {'name': 'Student_60', 'surname': 'Surname', 'email': 'Surname_60', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_60'}
# 2024-03-17 15:57:10,990 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:11,044 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:11,045 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:11,045 INFO sqlalchemy.engine.Engine [cached since 12.86s ago] {'name': 'Student_61', 'surname': 'Surname', 'email': 'Surname_61', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_61'}
# 2024-03-17 15:57:11,177 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:11,464 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:11,467 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:11,476 INFO sqlalchemy.engine.Engine [cached since 13.29s ago] {'name': 'Student_62', 'surname': 'Surname', 'email': 'Surname_62', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_62'}
# 2024-03-17 15:57:11,592 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:11,647 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:11,648 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:11,649 INFO sqlalchemy.engine.Engine [cached since 13.46s ago] {'name': 'Student_63', 'surname': 'Surname', 'email': 'Surname_63', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_63'}
# 2024-03-17 15:57:11,762 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:11,825 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:11,827 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:11,827 INFO sqlalchemy.engine.Engine [cached since 13.64s ago] {'name': 'Student_64', 'surname': 'Surname', 'email': 'Surname_64', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_64'}
# 2024-03-17 15:57:11,947 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:12,008 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:12,009 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:12,009 INFO sqlalchemy.engine.Engine [cached since 13.82s ago] {'name': 'Student_65', 'surname': 'Surname', 'email': 'Surname_65', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_65'}
# 2024-03-17 15:57:12,121 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:12,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:12,180 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:12,180 INFO sqlalchemy.engine.Engine [cached since 13.99s ago] {'name': 'Student_66', 'surname': 'Surname', 'email': 'Surname_66', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_66'}
# 2024-03-17 15:57:12,277 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:12,345 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:12,346 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:12,347 INFO sqlalchemy.engine.Engine [cached since 14.16s ago] {'name': 'Student_67', 'surname': 'Surname', 'email': 'Surname_67', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_67'}
# 2024-03-17 15:57:12,453 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:12,557 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:12,560 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:12,561 INFO sqlalchemy.engine.Engine [cached since 14.37s ago] {'name': 'Student_68', 'surname': 'Surname', 'email': 'Surname_68', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_68'}
# 2024-03-17 15:57:12,663 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:12,723 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:12,724 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:12,725 INFO sqlalchemy.engine.Engine [cached since 14.54s ago] {'name': 'Student_69', 'surname': 'Surname', 'email': 'Surname_69', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_69'}
# 2024-03-17 15:57:12,817 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:12,871 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:12,873 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:12,873 INFO sqlalchemy.engine.Engine [cached since 14.69s ago] {'name': 'Student_70', 'surname': 'Surname', 'email': 'Surname_70', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_70'}
# 2024-03-17 15:57:12,970 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:13,028 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:13,030 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:13,031 INFO sqlalchemy.engine.Engine [cached since 14.84s ago] {'name': 'Student_71', 'surname': 'Surname', 'email': 'Surname_71', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_71'}
# 2024-03-17 15:57:13,145 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:13,413 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:13,415 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:13,417 INFO sqlalchemy.engine.Engine [cached since 15.23s ago] {'name': 'Student_72', 'surname': 'Surname', 'email': 'Surname_72', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_72'}
# 2024-03-17 15:57:13,519 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:13,577 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:13,579 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:13,580 INFO sqlalchemy.engine.Engine [cached since 15.39s ago] {'name': 'Student_73', 'surname': 'Surname', 'email': 'Surname_73', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_73'}
# 2024-03-17 15:57:13,691 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:13,745 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:13,747 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:13,747 INFO sqlalchemy.engine.Engine [cached since 15.56s ago] {'name': 'Student_74', 'surname': 'Surname', 'email': 'Surname_74', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_74'}
# 2024-03-17 15:57:13,855 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:13,923 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:13,924 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:13,924 INFO sqlalchemy.engine.Engine [cached since 15.74s ago] {'name': 'Student_75', 'surname': 'Surname', 'email': 'Surname_75', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_75'}
# 2024-03-17 15:57:14,021 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:14,074 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:14,075 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:14,076 INFO sqlalchemy.engine.Engine [cached since 15.89s ago] {'name': 'Student_76', 'surname': 'Surname', 'email': 'Surname_76', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_76'}
# 2024-03-17 15:57:14,172 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:14,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:14,224 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:14,225 INFO sqlalchemy.engine.Engine [cached since 16.04s ago] {'name': 'Student_77', 'surname': 'Surname', 'email': 'Surname_77', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_77'}
# 2024-03-17 15:57:14,338 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:14,395 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:14,396 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:14,397 INFO sqlalchemy.engine.Engine [cached since 16.21s ago] {'name': 'Student_78', 'surname': 'Surname', 'email': 'Surname_78', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_78'}
# 2024-03-17 15:57:14,510 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:14,567 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:14,568 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:14,569 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] {'name': 'Student_79', 'surname': 'Surname', 'email': 'Surname_79', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_79'}
# 2024-03-17 15:57:14,679 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:14,731 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:14,732 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:14,732 INFO sqlalchemy.engine.Engine [cached since 16.55s ago] {'name': 'Student_80', 'surname': 'Surname', 'email': 'Surname_80', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_80'}
# 2024-03-17 15:57:15,010 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:15,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:15,096 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:15,096 INFO sqlalchemy.engine.Engine [cached since 16.91s ago] {'name': 'Student_81', 'surname': 'Surname', 'email': 'Surname_81', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_81'}
# 2024-03-17 15:57:15,205 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:15,259 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:15,260 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:15,261 INFO sqlalchemy.engine.Engine [cached since 17.07s ago] {'name': 'Student_82', 'surname': 'Surname', 'email': 'Surname_82', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_82'}
# 2024-03-17 15:57:15,361 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:15,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:15,421 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:15,422 INFO sqlalchemy.engine.Engine [cached since 17.24s ago] {'name': 'Student_83', 'surname': 'Surname', 'email': 'Surname_83', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_83'}
# 2024-03-17 15:57:15,545 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:15,596 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:15,598 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:15,598 INFO sqlalchemy.engine.Engine [cached since 17.41s ago] {'name': 'Student_84', 'surname': 'Surname', 'email': 'Surname_84', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_84'}
# 2024-03-17 15:57:15,706 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 15:57:16,006 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 15:57:16,022 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 15:57:16,023 INFO sqlalchemy.engine.Engine [cached since 17.84s ago] {'name': 'Student_85', 'surname': 'Surname', 'email': 'Surname_85', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_85'}
# ...
# 2024-03-17 16:10:28,596 INFO sqlalchemy.engine.Engine [cached since 810.4s ago] {'name': 'Student_3688', 'surname': 'Surname', 'email': 'Surname_3688', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3688'}
# 2024-03-17 16:10:28,682 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:28,781 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:28,787 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:28,789 INFO sqlalchemy.engine.Engine [cached since 810.6s ago] {'name': 'Student_3689', 'surname': 'Surname', 'email': 'Surname_3689', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3689'}
# 2024-03-17 16:10:28,906 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:28,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:28,951 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:28,951 INFO sqlalchemy.engine.Engine [cached since 810.8s ago] {'name': 'Student_3690', 'surname': 'Surname', 'email': 'Surname_3690', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3690'}
# 2024-03-17 16:10:29,042 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:29,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:29,096 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:29,096 INFO sqlalchemy.engine.Engine [cached since 810.9s ago] {'name': 'Student_3691', 'surname': 'Surname', 'email': 'Surname_3691', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3691'}
# 2024-03-17 16:10:29,180 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:29,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:29,224 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:29,225 INFO sqlalchemy.engine.Engine [cached since 811.1s ago] {'name': 'Student_3692', 'surname': 'Surname', 'email': 'Surname_3692', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3692'}
# 2024-03-17 16:10:29,325 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:29,368 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:29,369 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:29,369 INFO sqlalchemy.engine.Engine [cached since 811.2s ago] {'name': 'Student_3693', 'surname': 'Surname', 'email': 'Surname_3693', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3693'}
# 2024-03-17 16:10:29,462 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:29,506 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:29,507 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:29,507 INFO sqlalchemy.engine.Engine [cached since 811.3s ago] {'name': 'Student_3694', 'surname': 'Surname', 'email': 'Surname_3694', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3694'}
# 2024-03-17 16:10:29,608 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:29,683 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:29,683 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:29,684 INFO sqlalchemy.engine.Engine [cached since 811.5s ago] {'name': 'Student_3695', 'surname': 'Surname', 'email': 'Surname_3695', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3695'}
# 2024-03-17 16:10:29,791 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:29,839 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:29,840 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:29,840 INFO sqlalchemy.engine.Engine [cached since 811.7s ago] {'name': 'Student_3696', 'surname': 'Surname', 'email': 'Surname_3696', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3696'}
# 2024-03-17 16:10:29,934 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,041 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,050 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,058 INFO sqlalchemy.engine.Engine [cached since 811.9s ago] {'name': 'Student_3697', 'surname': 'Surname', 'email': 'Surname_3697', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3697'}
# 2024-03-17 16:10:30,166 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,226 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,227 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,227 INFO sqlalchemy.engine.Engine [cached since 812.1s ago] {'name': 'Student_3698', 'surname': 'Surname', 'email': 'Surname_3698', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3698'}
# 2024-03-17 16:10:30,346 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,394 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,394 INFO sqlalchemy.engine.Engine [cached since 812.2s ago] {'name': 'Student_3699', 'surname': 'Surname', 'email': 'Surname_3699', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3699'}
# 2024-03-17 16:10:30,482 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,528 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,529 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,530 INFO sqlalchemy.engine.Engine [cached since 812.4s ago] {'name': 'Student_3700', 'surname': 'Surname', 'email': 'Surname_3700', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3700'}
# 2024-03-17 16:10:30,628 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,673 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,674 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,674 INFO sqlalchemy.engine.Engine [cached since 812.5s ago] {'name': 'Student_3701', 'surname': 'Surname', 'email': 'Surname_3701', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3701'}
# 2024-03-17 16:10:30,766 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,813 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,814 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,814 INFO sqlalchemy.engine.Engine [cached since 812.7s ago] {'name': 'Student_3702', 'surname': 'Surname', 'email': 'Surname_3702', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3702'}
# 2024-03-17 16:10:30,908 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:30,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:30,959 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:30,960 INFO sqlalchemy.engine.Engine [cached since 812.8s ago] {'name': 'Student_3703', 'surname': 'Surname', 'email': 'Surname_3703', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3703'}
# 2024-03-17 16:10:31,049 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:31,093 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:31,094 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:31,094 INFO sqlalchemy.engine.Engine [cached since 812.9s ago] {'name': 'Student_3704', 'surname': 'Surname', 'email': 'Surname_3704', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3704'}
# 2024-03-17 16:10:31,185 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:31,229 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:31,230 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:31,230 INFO sqlalchemy.engine.Engine [cached since 813.1s ago] {'name': 'Student_3705', 'surname': 'Surname', 'email': 'Surname_3705', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3705'}
# 2024-03-17 16:10:31,318 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:31,366 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:31,366 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:31,367 INFO sqlalchemy.engine.Engine [cached since 813.2s ago] {'name': 'Student_3706', 'surname': 'Surname', 'email': 'Surname_3706', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3706'}
# 2024-03-17 16:10:31,487 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:31,529 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:31,529 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:31,530 INFO sqlalchemy.engine.Engine [cached since 813.4s ago] {'name': 'Student_3707', 'surname': 'Surname', 'email': 'Surname_3707', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3707'}
# 2024-03-17 16:10:31,635 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-17 16:10:31,688 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-17 16:10:31,690 INFO sqlalchemy.engine.Engine INSERT INTO student (name, surname, email, birthdate, address) VALUES (%(name)s, %(surname)s, %(email)s, %(birthdate)s, %(address)s) RETURNING student.id
# 2024-03-17 16:10:31,691 INFO sqlalchemy.engine.Engine [cached since 813.5s ago] {'name': 'Student_3708', 'surname': 'Surname', 'email': 'Surname_3708', 'birthdate': datetime.datetime(2000, 1, 1, 0, 0), 'address': 'Address_3708'}
# 2024-03-17 16:10:31,832 INFO sqlalchemy.engine.Engine COMMIT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 session.rollback()
# ----> 2 test_10000_student_creation_performance()
#
# Cell In[15], line 4, in test_10000_student_creation_performance()
#       2 start_time = datetime.now()
#       3 for i in range(10000):
# ----> 4     create_new_student(f"Student_{i+1}", "Surname", f"Surname_{i+1}", datetime(2000, 1, 1), f"Address_{i+1}")
#       5 end_time = datetime.now()
#       6 print(f"1000 students created in {end_time - start_time}")
#
# Cell In[14], line 9, in create_new_student(name, surname, email, birthdate, address)
#       7 student = Student(name=name, surname=surname, email=email, birthdate=birthdate, address=address)
#       8 session.add(student)
# ----> 9 session.commit()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1972, in Session.commit(self)
#    1969 if trans is None:
#    1970     trans = self._autobegin_t()
# -> 1972 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1264, in SessionTransaction.commit(self, _to_root)
#    1260 for conn, trans, should_commit, autoclose in set(
#    1261     self._connections.values()
#    1262 ):
#    1263     if should_commit:
# -> 1264         trans.commit()
#    1266 self._state = SessionTransactionState.COMMITTED
#    1267 self.session.dispatch.after_commit(self.session)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2632, in Transaction.commit(self)
#    2616 """Commit this :class:`.Transaction`.
#    2617
#    2618 The implementation of this may vary based on the type of transaction in
#    (...)
#    2629
#    2630 """
#    2631 try:
# -> 2632     self._do_commit()
#    2633 finally:
#    2634     assert not self.is_active
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2737, in RootTransaction._do_commit(self)
#    2734 assert self.connection._transaction is self
#    2736 try:
# -> 2737     self._connection_commit_impl()
#    2738 finally:
#    2739     # whether or not commit succeeds, cancel any
#    2740     # nested transactions, make this transaction "inactive"
#    2741     # and remove it as a reset agent
#    2742     if self.connection._nested_transaction:
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2708, in RootTransaction._connection_commit_impl(self)
#    2707 def _connection_commit_impl(self) -> None:
# -> 2708     self.connection._commit_impl()
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1149, in Connection._commit_impl(self)
#    1147     self.engine.dialect.do_commit(self.connection)
#    1148 except BaseException as e:
# -> 1149     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2359, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2357     else:
#    2358         assert exc_info[1] is not None
# -> 2359         raise exc_info[1].with_traceback(exc_info[2])
#    2360 finally:
#    2361     del self._reentrant_error
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1147, in Connection._commit_impl(self)
#    1145         self._log_info("COMMIT")
#    1146 try:
# -> 1147     self.engine.dialect.do_commit(self.connection)
#    1148 except BaseException as e:
#    1149     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/opt/anaconda3/envs/fundev/lib/python3.10/site-packages/sqlalchemy/engine/default.py:695, in DefaultDialect.do_commit(self, dbapi_connection)
#     694 def do_commit(self, dbapi_connection):
# --> 695     dbapi_connection.commit()
#
# KeyboardInterrupt:
